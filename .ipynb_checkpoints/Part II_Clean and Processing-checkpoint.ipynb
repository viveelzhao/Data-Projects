# %% [markdown]
# ###### 0. Loading libraries

# %%
# %matplotlib notebook
import requests
import os
from boto.s3.connection import S3Connection
from boto.s3.key import Key
from string import punctuation
import pandas as pd
import numpy as np
import re
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# ###### 1. Setting global variables

# %%
CRAWLER_SWITCH = False
S3_IO = False
ACCESS_KEY = ""
SECRET_KEY = "/"
BUCKET_NAME = 'parks101'
READ_SWITCH = True
WRITE_SWITCH = False
FIT_SWITCH = True
DATA_FOLDER = '/Users/Wei.Zhao/Documents/Python code/tripadvisor/'
MODEL_FOLDER = '/Users/Wei.Zhao/Documents/Python code/tripadvisor/models/'
PARK_INFO_FILE = 'parks_info.csv'
REVIEW_RAW_FILE = 'reviews_raw.csv'
CLEAN_PARK_INFO_FILE = 'parks_info_clean.csv'
CLEAN_REVIEW_FILE = 'reviews_clean.csv'

# %% [markdown]
# ###### 2. Read Data

# %%
review_df_columns = ['index', 'comments', 'date', 'park_id', 'stars', 'title', 'reviewer_level', 'reviewer']
review_df_dtypes = {'index': np.int32, 
                    'comments': str, 
                    'date': str, 
                    'park_id': np.int32, 
                    'stars': np.int32, 
                    'title': str, 
                    'reviewer_level': np.int32, 
                    'reviewer': str}
if S3_IO:
    s3_handle = S3Connection(ACCESS_KEY, SECRET_KEY)
    bucket_handle = s3_handle.get_bucket(BUCKET_NAME)
    file_handle = Key(bucket_handle)
    file_handle.key = PARK_INFO_FILE
    file_handle.open()
    parks_info_df = pd.read_csv(file_handle, index_col=0)
    file_handle.close()
    file_handle.key = REVIEW_RAW_FILE
    file_handle.open()
    review_raw_df = pd.read_csv(file_handle, index_col=0, header=0)
    file_handle.close()
else:
    parks_info_df = pd.read_csv(os.path.join(DATA_FOLDER, PARK_INFO_FILE), index_col=0)
    review_raw_df = pd.read_csv(os.path.join(DATA_FOLDER, REVIEW_RAW_FILE), names=review_df_columns)

# %% [markdown]
# * 2.1 *(optional)* to save date to S3

# %%
if S3_IO and WRITE_SWITCH:
    s3_handle = S3Connection(ACCESS_KEY, SECRET_KEY)
    bucket_handle = s3_handle.get_bucket(BUCKET_NAME)
    for onefile, df in zip((PARK_INFO_FILE, REVIEW_RAW_FILE), (parks_info_df, review_raw_df)):
        if onefile in [i.name for i in bucket_handle.list()]:
            file_exist = Key(bucket_handle)
            file_exist.key = onefile
            bucket_handle.delete_key(file_exist)
        new_file_handle = bucket_handle.new_key(onefile)
        new_file_handle.set_contents_from_string(df.to_csv())

# %% [markdown]
# * 2.2 Clean up park_info dataframe
#
#     + 2.2.1 Remove duplicate
#     + 2.2.2 Convert visit counts to integer
#     + 2.2.3 Count total visit numbers

# %%
print parks_info_df.count()['park_id']
parks_info_df.drop_duplicates(inplace=True)
print parks_info_df.count()['park_id']

column_names = parks_info_df.columns.values.tolist()[5:19]
for col in column_names:
    parks_info_df[col] = parks_info_df[col].apply(int)
    
def col_agg(x, inputCol, *weights):
    data_type = x[inputCol[0]]
    if not weights:
        if isinstance(data_type, (int, float, long)):
            return sum(x[i] for i in inputCol)
        elif isinstance(data_type, (str, object)):
            return ' '.join([x[i] for i in inputCol])
        return None
    else:
        if isinstance(data_type, (int, float, long)):
            return sum(x[i] * w for i, w in zip(inputCol, weights[0]))
        elif isinstance(data_type, (str, object)):
            return ' '.join([' '.join([x[i], ' ']) * w for i, w in zip(inputCol, weights[0])])
        return None

parks_info_df['total visit'] = parks_info_df.apply(lambda x: col_agg(x, ['Spring', 'Summer', 'Fall', 'Winter']), axis=1)
# Out:
# 1025
# 1025

# %%
parks_info_df.head(6)
# Out:
#    park_id                                               html  \
# 0      0.0  https://www.tripadvisor.com/Attraction_Review-...
# 1      1.0  https://www.tripadvisor.com/Attraction_Review-...
# 2      2.0  https://www.tripadvisor.com/Attraction_Review-...
# 3      3.0  https://www.tripadvisor.com/Attraction_Review-...
# 4      4.0  https://www.tripadvisor.com/Attraction_Review-...
# 5      5.0  https://www.tripadvisor.com/Attraction_Review-...
#
#                              name  \
# 0                    Central_Park
# 1       Hot_Springs_National_Park
# 2  Hawaii_Volcanoes_National_Park
# 3      Dry_Tortugas_National_Park
# 4                    Bryce_Canyon
# 5                     Balboa_Park
#
#                                               city       state  Excellent  \
# 0                                New_York_City_New        York      35444
# 1                                      Hot_Springs    Arkansas        210
# 2  Hawaii_Volcanoes_National_Park_Island_of_Hawaii          Ha       3424
# 3                            Key_West_Florida_Keys     Florida       2478
# 4                       Bryce_Canyon_National_Park        Utah       3329
# 5                                        San_Diego  California       4898
#
#    Very_good  Average  Poor  Terrible  Families  Couples  Friends  Solo  \
# 0       9112     1380   132        52     12377    15311     7739  2824
# 1         99       42    13         5        95      151       46    15
# 2        768      136    25        13      1168     1875      481   161
# 3        423       89    20        14       694     1561      478   112
# 4        293       31     6         2       815     1636      469   144
# 5       1349      201    39        12      1652     2004      899   430
#
#    Business  Spring  Summer   Fall  Winter  total visit
# 0      1144   11247   14390  11419    9064        46120
# 1         6     104     143     78      44          369
# 2        19    1150    1220    860    1136         4366
# 3        17     825     932    575     692         3024
# 4         8     783    1473   1100     305         3661
# 5       259    1931    1929   1271    1368         6499

# %% [markdown]
# * 2.3 Clean up review_raw dataframe
#     + 2.3.1 Remove duplicates
#     + 2.3.2 Convert counts into integers
#     + 2.3.3 Convert date string into datestamp
#     + 2.3.4 Remove punctuates from comment strings
#     + 2.3.5 Assign a weight to title string and combine with comments

# %%
print review_raw_df.count()['park_id']
review_raw_df.drop_duplicates(subset=['park_id', 'comments', 'reviewer'], inplace=True)
print review_raw_df.count()['park_id']
# Out:
# 1297806
# 1297575

# %%
def float2int(anum):
    if isinstance(anum, float):
        return int(anum)
    else:
        return anum

def str2date(astr):  
    months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
    date_s = re.search('(January|February|March|April|May|June|July|August|September|October|November|December).*?(\d{1,2}).*?(\d{4})', astr)
    m, d, y = date_s.group(1), date_s.group(2), date_s.group(3)                  
    return pd.Timestamp('-'.join([y, str(months.index(m) + 1), d]))

def remove_puncs(astr):
    astr = re.sub('div.*div','',astr)
    for s in punctuation:
        astr = astr.replace(s, '')
    return astr.lower()

# %%
review_raw_df
# Out:
#          index                                           comments  \
# 0            0  Utah is arguably one of the most scenic and ge...
# 1            1  Recently i and my wife visited this park in Se...
# 2            2  Zion is beautiful but crowded. You now have to...
# 3            3  This was our first visit to Zion National Park...
# 4            4  First, the scenery is so beautiful you could s...
# 5            5  This park is so beautiful. We could only drive...
# 6            6  A great resource. You could easily spend an en...
# 7            7  What a lucky state to have so many totally bea...
# 8            8  The Utah Travel Council does a very good job l...
# 9            0  The Desert Institute is the shining star of th...
# 10           1  I think that many folks drive right by Joshua ...
# 11           2  A week pass for the Joshua Tree National Park ...
# 12           3  This retreat center is nestled amid beautiful ...
# 13           4  i went there with a friend from work , we drov...
# 14           5  I&#39;ve been to Joshua Tree before to hike an...
# 15           6  Huge park, we hired a guide which enhanced the...
# 16           7  SO quiet and peaceful..Bring your guitar and a...
# 17           8  We spent a day at the park and thoroughly enjo...
# 18           0  The staff were friendly, helpful and informati...
# 19           1  Nice little information center with of course,...
# 20           2  Must visit. This small information center is j...
# 21           3  The Thompson Island Visitor Center of Acadia N...
# 22           4  This VIC is right off the road to MDI from the...
# 23           5  We had a great stop here and really got the la...
# 24           6  We rolled in on a Sunday &amp; before we heade...
# 25           7  If you decided to take a spur-of-the-moment tr...
# 26           8  This is the first visitor center that you will...
# 27           9  We want to thank the lady that was working on ...
# 28          10  Acadia National Park is a big place. Getting a...
# 29           0  Island Dreamer and our captain Hans were the b...
# ...        ...                                                ...
# 1297776  48045  We loved Central Park and wish we had spent mo...
# 1297777  48046  After hearing people rave about Central Park, ...
# 1297778  48047  Central Park truly is a gem! You can&#39;t ima...
# 1297779  48048  This was my first trip to NYC. My first glimps...
# 1297780  48049  As I first came to Central Park from the East ...
# 1297781  48050  Wow what a place. I really didn&#39;t know wha...
# 1297782  48051  I have been to NYC off and on since I was a ki...
# 1297783  48052  Everything, from the Wollman Ice Rink to early...
# 1297784  48053  We visited Central Park in March. The Gates we...
# 1297785  48054  Central Park was great! We were there during F...
# 1297786  48055  We wandered from 96th E through the Park. It w...
# 1297787  48056  One of the world&#39;s greatest urban parks. Y...
# 1297788  48057  We visited NY in the winter so the park was ra...
# 1297789  48058  You have to experience Central Park in a carri...
# 1297790  48059  everyone has seen Central Park on tv, in films...
# 1297791  48060  yes this is the most amazing place!!to think y...
# 1297792  48061  We travelled to New York in March 2004 and wal...
# 1297793  48062  Central Park was the best retirement gift I co...
# 1297794  48063  Central Park is like no other place I have eve...
# 1297795  48064  If you are planning a trip to Manhattan you ca...
# 1297796  48065  Central Park at first does seem a little overw...
# 1297797  48066  Central Park was a nice break from all the hub...
# 1297798  48067  Lovely place to visit. You need to walk it to ...
# 1297799  48068  Central Park can be so intimidating so I decid...
# 1297800  48069  We stayed at the Sheraton Manhatten and walked...
# 1297801  48070  To arrive at Central Park to the scene of the ...
# 1297802  48071  Every time I return to NYC my wife and I have ...
# 1297803  48072  We took our 5yr old on a 4 day jaunt to NYC. C...
# 1297804  48073  What can I say? Central Park is a treasure. Go...
# 1297805  48074  Having been to New York City three times now, ...
#
#                        date  park_id  stars  \
# 0        September 26, 2015    759.0    3.0
# 1          October 14, 2013    759.0    5.0
# 2          October 10, 2013    759.0    3.0
# 3        September 19, 2013    759.0    5.0
# 4           August 29, 2013    759.0    5.0
# 5        September 29, 2012    759.0    4.0
# 6              May 21, 2012    759.0    4.0
# 7             April 7, 2012    759.0    5.0
# 8         December 22, 2011    759.0    5.0
# 9              May 19, 2015    873.0    5.0
# 10         January 29, 2015    873.0    5.0
# 11            June 12, 2013    873.0    5.0
# 12         October 21, 2012    873.0    4.0
# 13       September 12, 2012    873.0    5.0
# 14            April 3, 2012    873.0    5.0
# 15        February 22, 2012    873.0    4.0
# 16         February 7, 2012    873.0    5.0
# 17        December 29, 2011    873.0    5.0
# 18         November 2, 2016    467.0    4.0
# 19       September 15, 2016    467.0    5.0
# 20        September 6, 2016    467.0    5.0
# 21            July 18, 2016    467.0    4.0
# 22             July 9, 2016    467.0    3.0
# 23       September 20, 2015    467.0    5.0
# 24          August 27, 2015    467.0    3.0
# 25            July 24, 2015    467.0    4.0
# 26             June 2, 2014    467.0    4.0
# 27        September 2, 2013    467.0    5.0
# 28          August 29, 2012    467.0    5.0
# 29         November 7, 2016    926.0    5.0
# ...                     ...      ...    ...
# 1297776     October 8, 2005      0.0    5.0
# 1297777     August 22, 2005      0.0    3.0
# 1297778       July 19, 2005      0.0    5.0
# 1297779       July 16, 2005      0.0    5.0
# 1297780       July 16, 2005      0.0    5.0
# 1297781        May 11, 2005      0.0    5.0
# 1297782      April 26, 2005      0.0    5.0
# 1297783       April 1, 2005      0.0    5.0
# 1297784      March 26, 2005      0.0    5.0
# 1297785       March 3, 2005      0.0    5.0
# 1297786       March 2, 2005      0.0    5.0
# 1297787    January 16, 2005      0.0    5.0
# 1297788     January 8, 2005      0.0    4.0
# 1297789    December 7, 2004      0.0    5.0
# 1297790    December 5, 2004      0.0    5.0
# 1297791    December 5, 2004      0.0    5.0
# 1297792    October 20, 2004      0.0    5.0
# 1297793  September 13, 2004      0.0    5.0
# 1297794  September 12, 2004      0.0    5.0
# 1297795      August 8, 2004      0.0    5.0
# 1297796        July 5, 2004      0.0    5.0
# 1297797       June 19, 2004      0.0    5.0
# 1297798        June 4, 2004      0.0    4.0
# 1297799        May 19, 2004      0.0    5.0
# 1297800      April 22, 2004      0.0    2.0
# 1297801       March 2, 2004      0.0    5.0
# 1297802    January 12, 2004      0.0    5.0
# 1297803     October 8, 2003      0.0    5.0
# 1297804     August 24, 2003      0.0    5.0
# 1297805        June 7, 2003      0.0    5.0
#
#                                                      title  reviewer_level  \
# 0                Helpful with your Utah vacation planning.             6.0
# 1                                    Shame on us Americans             1.0
# 2                                    Beautiful but crowded             5.0
# 3                                  Wow! Zion is beautiful!             4.0
# 4                         Zion National Park does it right             6.0
# 5                                           Beautiful park             6.0
# 6                                  Utah travel information             4.0
# 7                                Utah&#39;s National Parks             4.0
# 8                                      Utah Travel Council             5.0
# 9                                     A learned adventure!             3.0
# 10                                           Dont miss it!             0.0
# 11                               Joshua Tree National Park             5.0
# 12                              Joshua Tree Retreat Center             5.0
# 13                               Joshua Tree National Park             6.0
# 14       Absolutely beautiful place to take pictures an...             5.0
# 15                                     Like another planet             3.0
# 16                                             Go trekking             2.0
# 17                                 Something for everyone.             0.0
# 18                             A great welcome to the park             5.0
# 19       Stop in to collect one of 12 park stamps avail...             6.0
# 20       All the facilities and information minus the q...             5.0
# 21               AN ACADIA NATIONAL PARK PASS SALES OFFICE             6.0
# 22                                               Easy stop             6.0
# 23                                     Greatest adventure              5.0
# 24                                            Sunday blues             6.0
# 25       Very helpful staff - especially useful with fi...             6.0
# 26                             Good place to get some info             6.0
# 27                                          Volunteers Tip             5.0
# 28                        One stop Mt. Desert Island Info.             4.0
# 29                     Absolutely the best park experience             5.0
# ...                                                    ...             ...
# 1297776  What would New York City be without Central Park?             0.0
# 1297777                Nothing special, just a quiet place             5.0
# 1297778         Amazing - Best park I&#39;ve ever been to!             4.0
# 1297779                           They do have trees!! :-)             3.0
# 1297780                                  MUST-SEE NUMBER 1             4.0
# 1297781                                      amazing place             5.0
# 1297782  Now I see why this is one of the most visited ...             5.0
# 1297783                  Central Park - a must visit place             4.0
# 1297784                                        A must see!             1.0
# 1297785                                             A must             6.0
# 1297786                        Did I have a saffron dream?             6.0
# 1297787                                       Just wander!             2.0
# 1297788                         A beautiful place to visit             4.0
# 1297789                                    An Amazing Ride             3.0
# 1297790                    The most amazing place on earth             0.0
# 1297791                               most amazing place!!             4.0
# 1297792                         Central Park in the Winter             0.0
# 1297793                            My Grandchildren Summer             0.0
# 1297794                                    Heaven on Earth             4.0
# 1297795                                       Central Park             0.0
# 1297796                              We Loved Central Park             0.0
# 1297797                          Central Park a nice break             0.0
# 1297798                                          Beautiful             3.0
# 1297799                        Central Park Walking Tours!             0.0
# 1297800                                   Not for Visitors             4.0
# 1297801                                            Magical             1.0
# 1297802                             return to central park             0.0
# 1297803                                  Autum in New Tork             4.0
# 1297804    Best park in the world, Best city in the world!             0.0
# 1297805                           A Little Piece of Heaven             0.0
#
#                    reviewer
# 0            podrozniczka60
# 1                prpatel007
# 2             Flybob6334580
# 3        JaniceWriterAuthor
# 4               Beachgal003
# 5                 Heather R
# 6                jaygee1941
# 7                    RPRINC
# 8                   Tanya M
# 9                   Diana S
# 10                   Adam P
# 11                  Thaiahh
# 12                  Kathy H
# 13            aprildoornbos
# 14                cmincalif
# 15            Christopher H
# 16                  Dixie W
# 17                  Malfer1
# 18                 432geoff
# 19                  Peter R
# 20          navintandon2016
# 21                Maurene_K
# 22                AndyB5542
# 23                Chelsey W
# 24                ccindyk48
# 25              Catherine C
# 26             HelenaGuerra
# 27                  David I
# 28                RideMaine
# 29                  Ernie B
# ...                     ...
# 1297776             unknown
# 1297777              nipon4
# 1297778         Pinkcustard
# 1297779          scobnurse1
# 1297780               Kalle
# 1297781            Nicci_UK
# 1297782               caron
# 1297783         DukeofMilan
# 1297784             sjh2005
# 1297785     Montreal_native
# 1297786              spatan
# 1297787        questioner29
# 1297788              LAGirl
# 1297789          mstamigirl
# 1297790             unknown
# 1297791         shellie2004
# 1297792             unknown
# 1297793             unknown
# 1297794              sports
# 1297795             unknown
# 1297796             unknown
# 1297797             unknown
# 1297798      CallawayDenver
# 1297799             unknown
# 1297800          lovlilynne
# 1297801            Bellgill
# 1297802             unknown
# 1297803         jtbroderick
# 1297804             unknown
# 1297805             unknown
#
# [1297575 rows x 8 columns]

# %%
review_clean_df=[]

# %%
cols = ['park_id', 'index', 'reviewer', 'reviewer_level', 'date', 'stars', 'title', 'comments']
newcols = ['park_id', 'review_index', 'reviewer', 'reviewer_level', 'date', 'stars', 'title', 'comments']
funs = [float2int, float2int, None, float2int, str2date, float2int, remove_puncs, remove_puncs]
review_clean_df = pd.DataFrame()
for i, col in enumerate(cols):
    if funs[i]:
        review_clean_df[newcols[i]] = review_raw_df[col].apply(funs[i])
    else:
        review_clean_df[newcols[i]] = review_raw_df[col]

# %%
title_weight = 1
review_clean_df['comments'] = review_clean_df.apply(lambda x: col_agg(x, 
                                                                      ['title', 'comments'], 
                                                                      (title_weight, 1)), 
                                                    axis=1)

# %%
review_clean_df.iloc[0]['comments']
# Out:
# 'helpful with your utah vacation planning   utah is arguably one of the most scenic and geologically interesting states in usa to see all the southern utah attractions one can obtain information and maps from the utah travel and tourism sites or information centers utah has also 45 state parks  east zion tourism council provides maps weather information and helpful advice for visiting zion national park  '

# %% [markdown]
# ###### 3. Save cleaned dataframe

# %%
parks_info_df.to_csv(os.path.join(DATA_FOLDER, CLEAN_PARK_INFO_FILE), header=True)
review_clean_df.to_csv(os.path.join(DATA_FOLDER, CLEAN_REVIEW_FILE), header=True)
