# %% [markdown]
# ###### 0. Read Libraries

# %%
import pandas as pd
import numpy as np
import re
import os
import random
from boto.s3.connection import S3Connection
from boto.s3.key import Key
from scipy.sparse.csr import csr_matrix
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.cross_validation import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.grid_search import GridSearchCV
from sklearn.linear_model import SGDClassifier
from sklearn.decomposition import TruncatedSVD
from sklearn.externals import joblib
from sklearn import metrics
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from math import ceil
from itertools import product
# %matplotlib notebook

# %% [markdown]
# ###### 1. Setting global variables

# %%
FIT_SWITCH = True
DATA_FOLDER = '/Users/Wei.Zhao/Documents/Python code/tripadvisor/'
MODEL_FOLDER = '/Users/Wei.Zhao/Documents/Python code/tripadvisor/models/SGD'
PARK_ASSIGNMENT_FILE ='park_assignment.csv'
CLEAN_PARK_INFO_FILE = 'parks_info_final.csv'
CLEAN_REVIEW_FILE = 'reviews_clean.csv'

# %% [markdown]
# ###### 2. Read Data from saved cleaned dataframes.

# %%
park_info_df=pd.read_csv(os.path.join(DATA_FOLDER,CLEAN_PARK_INFO_FILE))
park_assignment_df = pd.read_csv(os.path.join(DATA_FOLDER, PARK_ASSIGNMENT_FILE), index_col=0)
review_df = pd.read_csv(os.path.join(DATA_FOLDER, CLEAN_REVIEW_FILE), index_col=0)
review_df = pd.merge(review_df,park_assignment_df[['park_id','cluster_assignment']],on='park_id')
review_df.head(5)
# Out:
#    park_id  review_index            reviewer  reviewer_level        date  \
# 0      759             0      podrozniczka60               6  2015-09-26
# 1      759             1          prpatel007               1  2013-10-14
# 2      759             2       Flybob6334580               5  2013-10-10
# 3      759             3  JaniceWriterAuthor               4  2013-09-19
# 4      759             4         Beachgal003               6  2013-08-29
#
#    stars                                     title  \
# 0      3  helpful with your utah vacation planning
# 1      5                     shame on us americans
# 2      3                     beautiful but crowded
# 3      5                     wow zion is beautiful
# 4      5          zion national park does it right
#
#                                             comments  cluster_assignment
# 0  helpful with your utah vacation planning   uta...                   0
# 1  shame on us americans   recently i and my wife...                   0
# 2  beautiful but crowded   zion is beautiful but ...                   0
# 3  wow zion is beautiful   this was our first vis...                   0
# 4  zion national park does it right   first the s...                   0

# %% [markdown]
# ###### 3. Classification of parks based on every comment using park_id as label

# %%
'''separate parks by cluster assignment label'''
def subset_group(cluster_num):   
    df = review_df[review_df['cluster_assignment']==cluster_num]
    return df

# %%
'''SGDClassifer'''
def pipeline_build(park_weight):
    pipeline = Pipeline([('vect', TfidfVectorizer(strip_accents='unicode',
                                                  max_df = 0.6,
                                                  token_pattern = r'\b\w+\b',
                                                  ngram_range=(1,1),
                                                  min_df=2,
                                                  stop_words='english')),
                         ('clf', SGDClassifier(penalty='l2',class_weight = park_weight,
                                               fit_intercept=True,learning_rate='optimal',
                                               shuffle=True,n_iter=500,
                                               random_state=0))])
    param_grid = {'clf__alpha':[1e-5,1e-4],
                  'clf__loss':['hinge','log']
                  }


    search_grid = GridSearchCV(estimator=pipeline, 
                               param_grid=param_grid, 
                               verbose=1,n_jobs=-1,
                               refit=True)
    return search_grid

# %%
'''get top 20 words with highest coefficient for classification'''
def park_features_extract(best_model):
    class_label = best_model.named_steps['clf'].classes_
    for i,j in enumerate(class_label):
        feature_map = best_model.named_steps['vect'].get_feature_names()
        wt = best_model.named_steps['clf'].coef_[i]
        feature_scores = sorted(zip(feature_map, wt),key=lambda x:x[1],reverse=True)[0:20]
        feature_words=[k[0] for k in feature_scores[0:20]]
        park_features[j]=feature_words
    return park_features

# %%
'''funtions for saving the fitted model or load in fitted model from local''' 
def save_best_model(CV_search_grid,group_id):
     
    model_file_name = 'SGD_group_model'+'_'+str(group_id)+'.pkl'
    grid_file_name = 'SGD_group_grid'+'_'+str(group_id)+'.pkl'
    joblib.dump(CV_search_grid.best_estimator_, os.path.join(MODEL_FOLDER, model_file_name))
    joblib.dump(CV_search_grid.grid_scores_,os.path.join(MODEL_FOLDER, grid_file_name))
    
def load_best_model(file_path, group_id):
    model_file_name = 'SGD_group_model'+'_'+str(group_id)+'.pkl'
    grid_file_name = 'SGD_group_grid'+'_'+str(group_id)+'.pkl'
    best_model = joblib.load(os.path.join(MODEL_FOLDER, model_file_name))
    grid_score=joblib.load(os.path.join(MODEL_FOLDER,grid_file_name))
    return best_model,grid_score

# %%
total_clusters = 15
correct_rate = {}
park_features = {}

if FIT_SWITCH:
    for i in range(total_clusters):
        subset_df = subset_group(i)
        if i!=2: #cluster 2 has too many classes to efficiently implement classification algorithm
            park_reviews = subset_df.groupby('park_id', as_index=False).size()
            '''pre calculate class weight by park frequency in each cluster '''
            park_weight = (park_reviews/float(park_reviews.sum())).to_dict()
            '''splitting into train and test dataframe'''
            train_f, test_f, train_parkid, test_parkid = train_test_split(subset_df['comments'], 
                                                                          subset_df['park_id'],
                                                                          test_size=0.2,
                                                                          random_state=0)
      
            search_grid = pipeline_build(park_weight)
            search_grid.fit(train_f,train_parkid)
            best_estimator=search_grid.best_estimator_
            grid_scores=search_grid.grid_scores_
            '''saving fitted model for each cluster'''
            save_best_model(search_grid,group_id=i)         
            test_results = best_estimator.predict(test_f)
            '''calculate classification correct rate'''
            correct_rate[i] = np.mean(test_results == test_parkid)
            '''get top 20 words with highest coefficient for classification'''
            park_features = park_features_extract(best_estimator)
        else:
            continue
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed: 11.6min finished
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed: 14.8min finished
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:  1.8min finished
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:  1.9min finished
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:  2.1min finished
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:  2.1min finished
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:  2.5min finished
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:  1.7min finished
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:  1.3min finished
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed: 70.6min finished
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:  5.1min finished
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:  2.0min finished
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:   49.2s finished
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:  2.7min finished

# %%
classification_rate_df = pd.DataFrame(correct_rate.items(),columns=['cluster_assignment','correct_rate'])
classification_rate_df.to_csv('/Users/Wei.Zhao/Documents/Python code/tripadvisor/class_error.csv')
if FIT_SWITCH == True:
    feature_df = pd.DataFrame(park_features.items(),columns=['park_id','features'] )
    feature_df.to_csv('/Users/Wei.Zhao/Documents/Python code/tripadvisor/park_features.csv')
else:
    feature_df = pd.read_csv('/Users/Wei.Zhao/Documents/Python code/tripadvisor/park_features.csv',index_col=0)[['park_id','features']]
    classitication_rate_df=pd.read_csv('/Users/Wei.Zhao/Documents/Python code/tripadvisor/class_error.csv',index_col=0)

# %%
cluster_df = (review_df[['cluster_assignment','park_id']].drop_duplicates()
              .groupby('cluster_assignment',as_index=False)
              .count())
cluster_df.rename(columns={'park_id':'cluster_size'},inplace=True)
pd.merge(classification_rate_df,cluster_df,on='cluster_assignment')
# Out:
#     cluster_assignment  correct_rate  cluster_size
# 0                    0      0.489641            67
# 1                    1      0.828521            71
# 2                    3      0.679580            30
# 3                    4      0.689094            41
# 4                    5      0.610309            42
# 5                    6      0.728801            38
# 6                    7      0.668216            43
# 7                    8      0.708766            29
# 8                    9      0.734301            32
# 9                   10      0.698400            83
# 10                  11      0.600995            62
# 11                  12      0.768607            19
# 12                  13      0.610541            27
# 13                  14      0.703988            41

# %%
park_info_assign_df = pd.merge(park_info_df,park_assignment_df, on='park_id')[['park_id','name','park_features']]
classification_summary_df = pd.merge(park_info_assign_df,feature_df,on='park_id' )
pd.set_option('display.max_colwidth',-1)
classification_summary_df.rename(columns={'park_features': 'kmeans_tfidf_top_features', 'features': 'classfication features'}, inplace=True)
classification_summary_df
# Out:
#      park_id                                             name  \
# 0    2.0      Hawaii Volcanoes National Park
# 1    3.0      Dry Tortugas National Park
# 2    4.0      Bryce Canyon
# 3    5.0      Balboa Park
# 4    6.0      Arches National Park
# 5    8.0      Grand Canyon National Park
# 6    9.0      Mount Desert Island
# 7    10.0     Acadia National Park
# 8    11.0     Hersheypark
# 9    12.0     Yosemite Valley
# 10   14.0     Grand Teton
# 11   15.0     Nationals Park
# 12   16.0     Kenai Fjords National Park
# 13   18.0     Theodore Roosevelt National Park
# 14   19.0     Park Loop Road
# 15   20.0     Capitol Reef National Park
# 16   21.0     Biscayne National Park
# 17   22.0     Mount Rainier
# 18   23.0     Zion Canyon Scenic Drive
# 19   24.0     Custer State Park
# 20   27.0     Grand Canyon South Rim
# 21   28.0     Padre Island National Seashore
# 22   29.0     Cabrillo National Monument
# 23   30.0     Trail Ridge Road
# 24   32.0     Denali
# 25   34.0     Images of Rocky Mountain National Park
# 26   35.0     Dead Horse Point State Park
# 27   38.0     National Geographic Grand Canyon Visitor Center
# 28   39.0     Magic Kingdom
# 29   40.0     PNC Park
# ..    ...          ...
# 595  991.0    Grizzly Country Wildlife Adventures
# 596  992.0    The Art Institute of Chicago
# 597  994.0    Ernest F Coe Visitor Center
# 598  996.0    Hetch Hetchy Reservoir
# 599  997.0    Glacier Raft Company
# 600  998.0    San Juan Island National Historical Park
# 601  999.0    Silver Falls State Park
# 602  1005.0   NAVTEC Expeditions Day Tours
# 603  1009.0   Fort Vancouver National Historic Site
# 604  1010.0   Salt Springs Recreation Area
# 605  1011.0   Biscuit Basin
# 606  1013.0   Double O Arch
# 607  1014.0   Mauka Makai Adventures
# 608  1015.0   Bear Lake Trailhead
# 609  1017.0   Gorham Mountain Trail
# 610  1018.0   San Juan Island National Historical Park
# 611  1019.0   Silver Falls State Park
# 612  1025.0   NAVTEC Expeditions Day Tours
# 613  1029.0   Fort Vancouver National Historic Site
# 614  1030.0   Salt Springs Recreation Area
# 615  1031.0   Biscuit Basin
# 616  1033.0   Double O Arch
# 617  1034.0   Mauka Makai Adventures
# 618  1035.0   Bear Lake Trailhead
# 619  1037.0   Gorham Mountain Trail
# 620  1038.0   McWay Falls
# 621  1041.0   Little Talbot Island State Park
# 622  1042.0   Tuolumne Grove of Giant Sequoias
# 623  1045.0   Moab Pathfinders
# 624  1047.0   Anna Ruby Falls
#
#                                                                                                                                                                                                                                                      kmeans_tfidf_top_features  \
# 0    [u'lava', u'volcano', u'crater', u'volcanoes', u'kilauea', u'steam', u'vents', u'tube', u'craters', u'island', u'hawaii', u'glow', u'jagger', u'caldera', u'jaggar', u'iki', u'thurston', u'kona', u'active', u'tubes']
# 1    [u'tortugas', u'snorkeling', u'fort', u'seaplane', u'ferry', u'boat', u'yankee', u'jefferson', u'snorkel', u'key', u'island', u'freedom', u'plane', u'breakfast', u'sea', u'fish', u'beach', u'crew', u'keys', u'iii']
# 2    [u'bryce', u'canyon', u'hoodoos', u'zion', u'rim', u'navajo', u'formations', u'utah', u'sunrise', u'shuttle', u'queens', u'queen39s', u'garden', u'rainbow', u'canyons', u'inspiration', u'peekaboo', u'hoodoo', u'viewpoints', u'fairyland']
# 3    [u'balboa', u'museums', u'diego', u'san', u'zoo', u'gardens', u'architecture', u'garden', u'organ', u'prado', u'botanical', u'art', u'buildings', u'japanese', u'spanish', u'science', u'rose', u'sd', u'restaurants', u'globe']
# 4    [u'arches', u'arch', u'delicate', u'moab', u'formations', u'utah', u'furnace', u'fiery', u'windows', u'double', u'garden', u'canyonlands', u'devil39s', u'devils', u'sunrise', u'balanced', u'avenue', u'dune', u'sand', u'canyon']
# 5    [u'canyon', u'rim', u'vegas', u'helicopter', u'las', u'shuttle', u'angel', u'justice', u'bucket', u'buses', u'sunrise', u'gc', u'skywalk', u'bright', u'mather', u'flagstaff', u'hoover', u'kaibab', u'tovar', u'lodge']
# 6    [u'acadia', u'harbor', u'island', u'cadillac', u'bar', u'desert', u'maine', u'mdi', u'mount', u'carriage', u'jordan', u'ocean', u'pond', u'lobster', u'mt', u'restaurants', u'biking', u'towns', u'coast', u'harbors']
# 7    [u'acadia', u'cadillac', u'jordan', u'carriage', u'harbor', u'pond', u'beach', u'bar', u'ocean', u'thunder', u'maine', u'hole', u'sand', u'popovers', u'sunrise', u'biking', u'jordan39s', u'coast', u'island', u'mt']
# 8    [u'hershey', u'rides', u'coasters', u'hersheypark', u'roller', u'amusement', u'chocolate', u'lines', u'coaster', u'waterpark', u'classpartialentryspan', u'tickets', u'theme', u'candylane', u'zoo', u'disney', u'christmas', u'boardwalk', u'kiddie', u'rollercoasters']
# 9    [u'yosemite', u'falls', u'waterfalls', u'capitan', u'dome', u'el', u'glacier', u'shuttle', u'granite', u'curry', u'village', u'floor', u'merced', u'mariposa', u'meadows', u'tioga', u'vernal', u'san', u'francisco', u'tunnel']
# 10   [u'teton', u'tetons', u'yellowstone', u'jackson', u'jenny', u'moose', u'lakes', u'elk', u'majestic', u'hole', u'snake', u'peaks', u'bison', u'gtnp', u'signal', u'boat', u'colter', u'wyoming', u'lodge', u'inspiration']
# 11   [u'stadium', u'nationals', u'ballpark', u'game', u'nats', u'baseball', u'metro', u'seats', u'ball', u'dc', u'fans', u'seat', u'games', u'ballparks', u'tickets', u'beer', u'mlb', u'field', u'team', u'ben39s']
# 12   [u'glacier', u'kenai', u'fjords', u'whales', u'glaciers', u'seward', u'puffins', u'boat', u'sea', u'otters', u'cruise', u'lions', u'exit', u'fjord', u'orcas', u'humpback', u'seals', u'harding', u'alaska', u'marine']
# 13   [u'bison', u'prairie', u'horses', u'badlands', u'buffalo', u'medora', u'unit', u'dakota', u'theodore', u'roosevelt', u'trnp', u'herds', u'teddy', u'deer', u'painted', u'units', u'canyon', u'roosevelt39s', u'nd', u'elk']
# 14   [u'acadia', u'cadillac', u'jordan', u'beach', u'thunder', u'sand', u'hole', u'ocean', u'maine', u'pond', u'harbor', u'otter', u'island', u'bar', u'cd', u'lane', u'oneway', u'cliffs', u'carriage', u'27']
# 15   [u'reef', u'capitol', u'utah', u'bryce', u'fruita', u'hickman', u'zion', u'arches', u'orchards', u'torrey', u'canyon', u'gifford', u'moab', u'petroglyphs', u'formations', u'canyonlands', u'capital', u'waterpocket', u'fruit', u'cassidy']
# 16   [u'biscayne', u'boat', u'underwater', u'miami', u'chita', u'bay', u'boca', u'keys', u'reefs', u'snorkeling', u'florida', u'canoe', u'snorkel', u'coral', u'fascell', u'kayak', u'fish', u'boardwalk', u'mangrove', u'fishing']
# 17   [u'rainier', u'paradise', u'mt', u'seattle', u'mount', u'sunrise', u'waterfalls', u'glaciers', u'nisqually', u'longmire', u'washington', u'ranier', u'rainer', u'wildflowers', u'falls', u'clouds', u'majestic', u'volcano', u'inn', u'narada']
# 18   [u'zion', u'canyon', u'shuttle', u'tunnel', u'springdale', u'bryce', u'vegas', u'tunnels', u'las', u'utah', u'formations', u'sheep', u'shuttles', u'narrows', u'lodge', u'buses', u'canyons', u'carmel', u'virgin', u'cliffs']
# 19   [u'custer', u'buffalo', u'bison', u'needles', u'burros', u'rushmore', u'sylvan', u'prairie', u'donkeys', u'antelope', u'deer', u'pronghorn', u'herd', u'hills', u'dakota', u'iron', u'tunnels', u'herds', u'roundup', u'mt']
# 20   [u'canyon', u'rim', u'vegas', u'helicopter', u'las', u'shuttle', u'angel', u'justice', u'bucket', u'buses', u'sunrise', u'gc', u'skywalk', u'bright', u'mather', u'flagstaff', u'hoover', u'kaibab', u'tovar', u'lodge']
# 21   [u'beach', u'padre', u'seashore', u'corpus', u'beaches', u'island', u'sand', u'christi', u'seaweed', u'malaquite', u'turtle', u'release', u'sea', u'turtles', u'texas', u'gulf', u'fishing', u'showers', u'surf', u'shells']
# 22   [u'diego', u'cabrillo', u'san', u'lighthouse', u'monument', u'tide', u'loma', u'pools', u'coronado', u'ocean', u'bay', u'pacific', u'tidepools', u'harbor', u'naval', u'cemetery', u'military', u'rosecrans', u'tidal', u'downtown']
# 23   [u'estes', u'ridge', u'elk', u'alpine', u'rmnp', u'tundra', u'rocky', u'moose', u'marmots', u'12000', u'sheep', u'colorado', u'highest', u'altitude', u'divide', u'rockies', u'scary', u'heights', u'continental', u'deer']
# 24   [u'denali', u'mckinley', u'caribou', u'moose', u'mt', u'alaska', u'clouds', u'sheep', u'tundra', u'talkeetna', u'dall', u'wilderness', u'bears', u'shuttle', u'mount', u'anchorage', u'eielson', u'driver', u'grizzly', u'princess']
# 25   [u'gallery', u'erik', u'estes', u'rmnp', u'images', u'erik39s', u'stensland', u'photography', u'rocky', u'prints', u'eric39s', u'stensland39s', u'photographer', u'photographs', u'art', u'purchased', u'purchase', u'captures', u'facebook', u'classpartialentryspan']
# 26   [u'canyonlands', u'moab', u'horse', u'dead', u'canyon', u'colorado', u'arches', u'rim', u'utah', u'thelma', u'canyons', u'canyonland', u'louise', u'biking', u'potash', u'sunrise', u'island', u'viewpoint', u'overlooks', u'campground']
# 27   [u'imax', u'canyon', u'classpartialentryspan', u'geographic', u'reviewmartyspan', u'againmartyspan', u'jeep', u'pink', u'travelsspan', u'pizza', u'hut', u'canyonpp', u'visitmartyspan', u'tusayan', u'theater', u'rim', u'souvenirs', u'gc', u'write', u'explorers']
# 28   [u'kingdom', u'magic', u'disney', u'rides', u'fireworks', u'parade', u'castle', u'parades', u'lines', u'characters', u'mk', u'fastpass', u'orlando', u'fantasyland', u'passes', u'mickey', u'happiest', u'christmas', u'theme', u'princesses']
# 29   [u'pnc', u'ballpark', u'baseball', u'game', u'stadium', u'pirates', u'pittsburgh', u'ball', u'seats', u'seat', u'mlb', u'clemente', u'ballparks', u'skyline', u'fans', u'bucs', u'downtown', u'field', u'games', u'roberto']
# ..                                                                                                                                                                                                                            ...
# 595  [u'yellowstone', u'jonathan', u'grizzly', u'teton', u'kris', u'jeff', u'jackson', u'tetons', u'daryl', u'bison', u'elk', u'adventures', u'moose', u'jonathon', u'michael', u'chris', u'wyoming', u'hole', u'mike', u'breakfast']
# 596  [u'art', u'institute', u'chicago', u'impressionist', u'collection', u'impressionists', u'paintings', u'gogh', u'collections', u'museums', u'monet', u'modern', u'exhibit', u'impressionism', u'wing', u'picasso', u'pieces', u'van', u'works', u'chagall']
# 597  [u'everglades', u'coe', u'ernest', u'flamingo', u'anhinga', u'alligators', u'alligator', u'florida', u'missile', u'f', u'herons', u'interactive', u'enp', u'intro', u'miami', u'nike', u'entering', u'desk', u'gator', u'introduction']
# 598  [u'hetchy', u'hetch', u'yosemite', u'reservoir', u'dam', u'wapama', u'falls', u'san', u'tunnel', u'francisco', u'evergreen', u'muir', u'waterfalls', u'waterfall', u'dammed', u'resevoir', u'john', u'o39shaughnessy', u'francisco39s', u'flooded']
# 599  [u'rafting', u'raft', u'glacier', u'flathead', u'rapids', u'whitewater', u'company', u'float', u'doc', u'fork', u'abby', u'pete', u'montana', u'travis', u'cody', u'jake', u'sam', u'rafted', u'slater', u'grc']
# 600  [u'juan', u'english', u'island', u'san', u'camps', u'pig', u'islands', u'war', u'amer', u'juan39s', u'beach', u'1859', u'occupying', u'occupation', u'british', u'ferry', u'eagles', u'england', u'18591872', u'armies39']
# 601  [u'falls', u'waterfalls', u'silver', u'oregon', u'waterfall', u'portland', u'salem', u'cabins', u'campground', u'lodge', u'silverton', u'moderate', u'oregon39s', u'swimming', u'cabin', u'creek', u'canyon', u'upper', u'camped', u'maple']
# 602  [u'navtec', u'canyonlands', u'rafting', u'4x4', u'arches', u'moab', u'chesler', u'canyon', u'canyoneering', u'fiery', u'jeep', u'colorado', u'furnace', u'rob', u'cataract', u'kevin', u'rapids', u'needles', u'brian', u'raft']
# 603  [u'fort', u'vancouver', u'blacksmith', u'buildings', u'hudson39s', u'trading', u'fur', u'pearson', u'blacksmiths', u'bay', u'northwest', u'garden', u'hudson', u'officers', u'barracks', u'pacific', u'officer39s', u'period', u'marshall', u'columbia']
# 604  [u'springs', u'salt', u'campground', u'ocala', u'swimming', u'snorkeling', u'rv', u'swim', u'camped', u'72', u'recreation', u'florida', u'primitive', u'rules', u'fish', u'manatee', u'crystal', u'hookups', u'snorkel', u'sewer']
# 605  [u'biscuit', u'basin', u'sapphire', u'geyser', u'geysers', u'pool', u'faithful', u'pools', u'yellowstone', u'mystic', u'boardwalk', u'springs', u'thermal', u'basins', u'falls', u'prismatic', u'boardwalks', u'erupt', u'bison', u'upper']
# 606  [u'arch', u'arches', u'double', u'o', u'partition', u'garden', u'devils', u'devil39s', u'strenuous', u'scrambling', u'heights', u'quotfinquot', u'fin', u'angel', u'fins', u'navajo', u'quotspinequot', u'primitive', u'scramble', u'doubleo']
# 607  [u'josh', u'jill', u'hilo', u'makai', u'mauka', u'island', u'volcano', u'kona', u'volcanoes', u'hawaii', u'lava', u'hawaiian', u'adventures', u'booked', u'joshua', u'company', u'hamakua', u'cruise', u'coffee', u'van']
# 608  [u'bear', u'nymph', u'trailhead', u'emerald', u'alberta', u'rmnp', u'dream', u'shuttle', u'lakes', u'falls', u'loch', u'estes', u'rocky', u'fern', u'glacier', u'gorge', u'moraine', u'haiyaha', u'fills', u'bierstadt']
# 609  [u'gorham', u'acadia', u'cadillac', u'beehive', u'ocean', u'beach', u'moderate', u'sand', u'cliffs', u'summit', u'mtn', u'thunder', u'otter', u'bowl', u'hikers', u'rocky', u'doable', u'strenuous', u'hole', u'climbed']
# 610  [u'juan', u'english', u'island', u'san', u'camps', u'pig', u'islands', u'war', u'amer', u'juan39s', u'beach', u'1859', u'occupying', u'occupation', u'british', u'ferry', u'eagles', u'england', u'18591872', u'armies39']
# 611  [u'falls', u'waterfalls', u'silver', u'oregon', u'waterfall', u'portland', u'salem', u'cabins', u'campground', u'lodge', u'silverton', u'moderate', u'oregon39s', u'swimming', u'cabin', u'creek', u'canyon', u'upper', u'camped', u'maple']
# 612  [u'navtec', u'canyonlands', u'rafting', u'4x4', u'arches', u'moab', u'chesler', u'canyon', u'canyoneering', u'fiery', u'jeep', u'colorado', u'furnace', u'rob', u'cataract', u'kevin', u'rapids', u'needles', u'brian', u'raft']
# 613  [u'fort', u'vancouver', u'blacksmith', u'buildings', u'hudson39s', u'trading', u'fur', u'pearson', u'blacksmiths', u'bay', u'northwest', u'garden', u'hudson', u'officers', u'barracks', u'pacific', u'officer39s', u'period', u'marshall', u'columbia']
# 614  [u'springs', u'salt', u'campground', u'ocala', u'swimming', u'snorkeling', u'rv', u'swim', u'camped', u'72', u'recreation', u'florida', u'primitive', u'rules', u'fish', u'manatee', u'crystal', u'hookups', u'snorkel', u'sewer']
# 615  [u'biscuit', u'basin', u'sapphire', u'geyser', u'geysers', u'pool', u'faithful', u'pools', u'yellowstone', u'mystic', u'boardwalk', u'springs', u'thermal', u'basins', u'falls', u'prismatic', u'boardwalks', u'erupt', u'bison', u'upper']
# 616  [u'arch', u'arches', u'double', u'o', u'partition', u'garden', u'devils', u'devil39s', u'strenuous', u'scrambling', u'heights', u'quotfinquot', u'fin', u'angel', u'fins', u'navajo', u'quotspinequot', u'primitive', u'scramble', u'doubleo']
# 617  [u'josh', u'jill', u'hilo', u'makai', u'mauka', u'island', u'volcano', u'kona', u'volcanoes', u'hawaii', u'lava', u'hawaiian', u'adventures', u'booked', u'joshua', u'company', u'hamakua', u'cruise', u'coffee', u'van']
# 618  [u'bear', u'nymph', u'trailhead', u'emerald', u'alberta', u'rmnp', u'dream', u'shuttle', u'lakes', u'falls', u'loch', u'estes', u'rocky', u'fern', u'glacier', u'gorge', u'moraine', u'haiyaha', u'fills', u'bierstadt']
# 619  [u'gorham', u'acadia', u'cadillac', u'beehive', u'ocean', u'beach', u'moderate', u'sand', u'cliffs', u'summit', u'mtn', u'thunder', u'otter', u'bowl', u'hikers', u'rocky', u'doable', u'strenuous', u'hole', u'climbed']
# 620  [u'mcway', u'falls', u'sur', u'waterfall', u'pfeiffer', u'beach', u'julia', u'burns', u'ocean', u'pch', u'coast', u'pacific', u'cove', u'california', u'hwy', u'coastline', u'tunnel', u'waterfalls', u'san', u'cliff']
# 621  [u'beach', u'talbot', u'jacksonville', u'beaches', u'island', u'florida', u'shells', u'sand', u'campground', u'driftwood', u'dunes', u'tide', u'amelia', u'jax', u'showers', u'marsh', u'campsites', u'unspoiled', u'fishing', u'boardwalk']
# 622  [u'grove', u'sequoias', u'mariposa', u'sequoia', u'tuolumne', u'giant', u'yosemite', u'downhill', u'redwoods', u'giants', u'uphill', u'tioga', u'2017', u'groves', u'merced', u'dead', u'fallen', u'toulomne', u'6100', u'trek']
# 623  [u'moab', u'arches', u'john', u'pathfinders', u'tyler', u'furnace', u'fiery', u'palmer', u'canyonlands', u'ff', u'abilitiesone', u'ffour', u'idresponse401674795we', u'pathfindersspan', u'crowdspp', u'sixtysomethings', u'suset', u'wetted', u'archeswe', u'trekker']
# 624  [u'falls', u'ruby', u'anna', u'helen', u'unicoi', u'waterfall', u'waterfalls', u'ga', u'uphill', u'benches', u'georgia', u'04', u'creek', u'incline', u'stream', u'chattahoochee', u'twin', u'platforms', u'decks', u'deck']
#
#                                                                                                                                                                                                                                               classfication features
# 0    [sulfur, park, kileaua, rd, petroglyphs, steam, ocean, 4000, house, volunteer, museums, coast, holei, chain, jagger39s, plan, iki, till, days, restaurant]
# 1    [snorkeling, dr, snorkeled, snorkel, seaplane, overnight, mudd, 170, swim, jellyfish, sea, torugas, np, fishes, ferry, clipper, cat, middle, reef, park]
# 2    [queens, hoodoos, navajoqueens, 8000, quothoodoosquot, fairytale, fairyland, sculptures, prairie, pronghorn, fins, paria, 39hoodoos39, pillars, inspiration, navaho, spike, bryce, 63, terracotta]
# 3    [balboa, organ, prado, museums, fleet, friendship, cottages, architecture, globe, man, village, spanish, imax, aerospace, timken, buildings, tuesdays, international, automotive, theater]
# 4    [delicate, hikes, garden, arches, windows, words, traffic, park, walks, earth, window, days, parks, quotwindowsquot, absolute, concentration, eyes, planet, cd, 2000]
# 5    [justiceplease, canyonwas, inlaw, inspiringi, peoplejust, fulfill, confronts, beholding, logde, volunteering, marketplace, beliefs, funfilled, luke, throws, colter39s, comercialised, 7000ft, godo, unspeakably]
# 6    [island, mdi, restaurants, shopping, harbors, fjord, stores, towns, outdoorsy, seal, harbours, touristy, quaint, southwest, june, adventures, dislike, wilderness, town, lakes]
# 7    [100th, park, parks, celebrating, midoctober, specifically, significant, proud, we39ve, beginners, treasure, parkthe, birthday, hiker, roadway, raining, rode, inches, maintenance, tremendous]
# 8    [hershey, hersheypark, chocolate, candylane, preview, sweetest, skyrush, zooamerica, hershey39s, boardwalk, factory, hersheyparkspan, springtime, fahrenheit, hersey, classpartialentryspan, runner, sweet, lodge, manager]
# 9    [bikes, valley, merced, bike, mirror, falls, cliffs, biking, waterfalls, april, stayed, curry, pines, paradise, shuttles, fresno, photographer, spring, visited, lodging]
# 10   [jenny, biking, mountains, grand, transfiguration, church, moose, towering, ferry, hiking, peaks, park, jackson, inspiration, coulter, wished, mountain, teton, lodging, mormon]
# 11   [nationals, dc, metro, nats, ben39s, chili, navy, presidents, capitol, capital, bowl, nat39s, alexandria, national39s, national, new, monument, mascots, monuments, recent]
# 12   [exit, harding, glacier, hike, icefield, field, saltwater, easy, rangers, bears, hiked, boat, park, np, land, accessible, lifetime, glaciers, fjord, years]
# 13   [medora, horses, trnp, nd, wild, southern, painted, sections, north, roosevelt39s, units, roosevelt, cattle, 36, cabin, park, teddy, 36mile, section, petrified]
# 14   [road, outs, pull, slowly, drive, sand, 27, places, stopping, portion, route, way, lane, areas, lanes, july, pulloffs, provides, times, cd]
# 15   [capitol, orchards, hickman, torrey, reef, gifford, wash, capital, pie, fruit, fold, pies, gorge, waterpocket, fruita, burr, cassidy, apples, np, mormon]
# 16   [park, center, biscayne, nice, water, boat, national, visitor, beautiful, great, miami, walk, enjoy, picnic, visitor39s, canoe, bay, underwater, area, small]
# 17   [mountain, seattle, northwest, mount, snow, summit, peak, sunrise, feet, clouds, road, spectacular, magnificent, stevens, driving, tacoma, meadows, climbers, august, majestic]
# 18   [concentrate, quotzion, curve, misses, whet, sinawawa, throne, fitting, drivequot, drive, laverkin, specially, pedestrians, 39cause, gopro, climbs, limits, uncommon, ideally, charts]
# 19   [sylvan, needles, state, park, tunnels, csp, needle, lodges, stockade, lakes, sp, roundup, cabin, jewel, lodging, legion, keystone, iron, single, safari]
# 20   [bussing, pushchairs, birthdays, yesit, silenced, immaculately, magnificentthere, 70th, rowed, justicequot, swear, brace, whow, canx, botton, canynon, selective, downhills, ritz, clever]
# 21   [padre, pins, releases, release, windsurfing, wheel, galveston, hatchlings, corpus, ridley, 4x4, jelly, malachite, cleaner, wheelchairs, marker, houston, baby, hall, drive]
# 22   [monument, explorers, view, tidepools, cabrillo39s, history, films, statue, pools, california, military, migration, gray, views, don39t, overlooks, sits, visit, explorer, 360]
# 23   [grand, ridge, tundra, continuous, rainbow, trr, 12000, road, tree, alpine, elk, marmots, marmot, rocky, cut, ute, treeline, communities, granby, thrilling]
# 24   [mountain, clouds, mckinley, talkeetna, cleared, cloud, visible, blessed, lucky, apparently, tallest, 70, 30, days, magnificent, covered, clear, chance, majestic, actually]
# 25   [gallery, images, erik, erik39s, stensland, purchased, prints, photography, photos, photographs, purchase, work, eric39s, estes, captures, photographer, pieces, pictures, facebook, rmnp]
# 26   [state, coffee, yurts, thelma, mountain, bikes, sad, rim, sunset, dhp, point, views, similar, ponds, biking, bike, horseshoe, gem, canyon, heard]
# 27   [classpartialentryspan, imax, movie, shop, review, pizza, reviewmartyspan, thank, againmartyspan, hut, write, visit, tickets, time, history, gift, good, film, geographic, jeep]
# 28   [castle, fantasyland, magic, magical, kingdom, mk, parades, mickey39s, dwarfs, mountain, fireworks, pirates, monorail, peter, parade, dumbo, princess, princesses, ferry, cinderella39s]
# 29   [pnc, pirates, pittsburgh, river, clemente, bucs, pirate, bridge, rivers, primanti, buccos, bridges, roberto, city, allegheny, skyline, clipper, primanti39s, quaker, pirate39s]
# ..                                                                                                                                                                                ...
# 595  [jonathan, grizzly, michael, kris, country, jeff, adventures, daryl, hunt, chelsea, jonathon, adventure, lunch, chris, half, breakfast, perfect, husband, tour, chelse]
# 596  [institute, thorne, aic, gothic, miniature, chagall, miniatures, nighthawks, chicago, bedroom, grande, windows, jatte, bedrooms, gothicquot, terzo, seurat39s, piano, seurat, paperweight]
# 597  [everglades, center, visitor, park, stop, exhibits, helpful, staff, information, good, displays, nice, rangers, great, informative, map, ranger, visit, friendly, place]
# 598  [reservoir, dam, hetchy, hetch, water, supply, wapama, interesting, san, evergreen, tunnel, main, gem, beauty, beaten, muir, valley, far, o39shaughnessy, history]
# 599  [travis, abby, doc, nate, pete, raft, kelsey, justin, grc, slater, jordan, lori, sport, george, lee, sam, blast, jay, h, tate]
# 600  [camp, english, american, island, juan, pig, rangers, camps, san, national, historical, war, interesting, islands, stop, history, interpretive, juan39s, pretty, knowledgable]
# 601  [oregon, excersize, willing, goregous, conference, longs, non, oregonian, trees, photographic, disappoint, farm, silver, primarily, northwest, sites, tiny, largest, walker, ferns]
# 602  [canyonlands, tour, navtech, rob, trip, navtec, guide, chesler, time, justin, canyons, care, did, canyoneering, kevin, run, ben, thrills, driving, incredible]
# 603  [aviation, williamsburg, portland, hudson, apple, officers, fireworks, marshal, nw, vancouver, event, house, path, blacksmith, version, local, overlooked, pearson, knew, hilton]
# 604  [springs, salt, campground, camping, spring, beautiful, clean, area, swimming, camp, water, staff, nice, rv, clear, great, ocala, sites, forest, place]
# 605  [blue, biscuit, think, great, boardwalks, time, pool, clear, entire, travel, bikes, pools, water, park, short, hotsprings, amazing, stop, mystic, bad]
# 606  [hike, arch, double, trail, arches, o, gets, rock, easy, walking, garden, make, beautiful, challenging, strenuous, sandy, cool, walk, heights, landscape]
# 607  [josh, island, jill, hilo, experience, wanted, owner, great, excursion, definitely, best, time, booked, couple, tour, extremely, personalized, days, recommend, knowledgeable]
# 608  [loch, water, park, bathrooms, isn39t, difficult, parking, trail, sure, said, hike, 8am, trails, finding, agree, snowshoe, snow, moment, ranger, ventured]
# 609  [trail, hike, views, boots, beehive, nice, beginning, mile, it39s, 50s, 11, away, blow, medium, traveled, herehttpseyesontheworldgirlwordpresscom20150216triptomaineandnewhampshire82148914ellsworthmaineandacadianationalpark, rest, climb, steps, definitely]
# 610  [camp, american, island, english, juan, camps, rangers, historical, pig, national, war, san, interesting, views, interpretive, beach, stop, eagles, history, knowledgable]
# 611  [cut, gold, alltime, twists, medium, sliver, silverton, map, marathon, nw, unique, oregon, figured, 42, 100, volunteers, seven, planned, cabins, classified]
# 612  [day, brian, navtec, geology, group, fun, driver, truck, trip, canyoneering, exceeded, groups, tory, did, rafting, matt, guide, tour, office, class]
# 613  [growing, i5, open, decorated, gardens, pioneers, vancouver, garden, bridge, kris, attractions, columbia, inhabitants, papers, thank, running, surprising, fireworks, gym, understand]
# 614  [springs, salt, campground, camping, spring, camp, area, beautiful, water, clean, swimming, staff, nice, great, forest, rv, picnic, camped, park, place]
# 615  [sapphire, good, time, great, effort, believe, pools, bit, mystic, little, awesome, colors, boardwalks, photos, outlet, blues, clear, nice, water, basins]
# 616  [hike, double, o, arch, landscape, rock, arches, beautiful, really, partition, make, walking, trail, gets, parts, park, easy, cool, strenuous, pretty]
# 617  [josh, jill, tour, trip, fun, day, hilo, islands, wonderful, local, joshua, personal, best, spots, history, experience, friendly, lunch, flexible, personable]
# 618  [trailhead, park, big, sure, snow, using, wasn39t, viewsrangers, head, turned, moment, went, rest, lake, year, sour, miles, disappointed, shoeing, won39t]
# 619  [hike, trail, perfect, recommend, acadia, saw, hikes, family, effort, parking, great, away, definitely, views, easier, rain, work, bit, years, climb]
# 620  [sur, mcway, beach, pfeiffer, julia, ocean, burns, pacific, pch, highway, coast, cove, big, hwy, house, coastal, 1, stop, coastline, whales]
# 621  [talbot, jacksonville, amelia, jax, fernandina, ne, northeast, island, mayport, a1a, unbearable, little, driftwood, hugenot, george, florida, cumberland, heckscher, hammock, fits]
# 622  [grove, hike, sequoias, closed, mile, mariposa, trees, tuolumne, dead, 2017, downhill, giants, giant, walk, it39s, paved, redwoods, path, uphill, road]
# 623  [john, tyler, moab, guide, pathfinders, guided, extremely, palmer, knowledgeable, tour, guides, fiery, furnace, professional, private, group, adventure, ff, arches, recommended]
# 624  [helen, ruby, anna, unicoi, ga, georgia, twin, 04, snakes, decks, smith, benches, person, platforms, adult, trout, 300, shop, 4, steep]
#
# [625 rows x 4 columns]

# %%
feature
