# %% [markdown]
# ###### 0. Read Libraries

# %%
import pandas as pd
import numpy as np
import re
import os
import random
from boto.s3.connection import S3Connection
from boto.s3.key import Key
from scipy.sparse.csr import csr_matrix
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.cross_validation import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.grid_search import GridSearchCV
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.preprocessing import Normalizer
from sklearn.decomposition import TruncatedSVD
from sklearn.externals import joblib
from sklearn import metrics
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from math import ceil
from itertools import product
# %matplotlib inline

# %% [markdown]
# ###### 1. Setting global variables

# %%
'''switches'''
park_info_from_S3 = False # read park info table True: read from S3, False: read from local
review_from_S3 = False # read review table True: read from S3, False: read from local
FIT_SWITCH = True # True: grid search, fitting data False: read fitted model from local
SAVE_SWTICH = True # True: save the cluster assignment and feature extracted to local

'''amazon S3'''
ACCESS_KEY = "AKIAIKA2BC55CZI5WSRQ" # S3 access key
SECRET_KEY = "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" #s3 secret key
BUCKET_NAME = 'parks101' #s3 bucket name

'''file path and file name'''
DATA_FOLDER = '/Users/Wei.Zhao/Documents/Python code/tripadvisor/'
MODEL_FOLDER = '/Users/Wei.Zhao/Documents/Python code/tripadvisor/models/kmeans/'
PARK_INFO_S3 = 'park_info_clean.csv'
PARK_INFO_local='parks_info.csv'
REVIEW_RAW_FILE = 'Reviews_raw.csv'
CLEAN_PARK_INFO_FILE = 'parks_info_final.csv'
CLEAN_REVIEW_FILE = 'reviews_clean.csv'

# %% [markdown]
# ###### 2. Read Data from saved cleaned dataframes.
# * Does not use pyspark due to community edition speed limitation

# %%
'''read in park info table'''
review_df_columns = ['index', 'comments', 'date', 'park_id', 'stars', 'title', 'reviewer_level', 'reviewer']
review_df_dtypes = {'index': np.int32, 
                    'comments': np.object, 
                    'date': str, 
                    'park_id': np.int32, 
                    'stars': np.int32, 
                    'title': str, 
                    'reviewer_level': np.int32, 
                    'reviewer': str}
if park_info_from_S3:
    s3_handle = S3Connection(ACCESS_KEY, SECRET_KEY)
    bucket_handle = s3_handle.get_bucket(BUCKET_NAME)
    file_handle = Key(bucket_handle)
    file_handle.key = PARK_INFO_S3
    file_handle.open()
    parks_info_df = pd.read_csv(file_handle, index_col=0)
    file_handle.close()
    parks_df.to_csv(os.path.join(DATA_FOLDER,os.path.join(DATA_FOLDER,CLEAN_PARK_INFO_FILE)))
else:
    parks_df = pd.read_csv(os.path.join(DATA_FOLDER, CLEAN_PARK_INFO_FILE), index_col=0)
    
'''read in review table'''
if review_from_S3: 
    file_handle.key = REVIEW_RAW_FILE
    file_handle.open()
    review_raw_df = pd.read_csv(file_handle, index_col=0, header=0)
    file_handle.close()
else:
    review_df = pd.read_csv(os.path.join(DATA_FOLDER, CLEAN_REVIEW_FILE), index_col=0)

# %%
parks_df.count()
# Out:
# park_id        1025
# html           1025
# name           1025
# city           1025
# state          1025
# Excellent      1025
# Very_good      1025
# Average        1025
# Poor           1025
# Terrible       1025
# Families       1025
# Couples        1025
# Friends        1025
# Solo           1025
# Business       1025
# Spring         1025
# Summer         1025
# Fall           1025
# Winter         1025
# total_visit    1025
# state_abb      1025
# dtype: int64

# %%
review_df
# Out:
#          park_id  review_index            reviewer  reviewer_level  \
# 0            759             0      podrozniczka60               6
# 1            759             1          prpatel007               1
# 2            759             2       Flybob6334580               5
# 3            759             3  JaniceWriterAuthor               4
# 4            759             4         Beachgal003               6
# 5            759             5           Heather R               6
# 6            759             6          jaygee1941               4
# 7            759             7              RPRINC               4
# 8            759             8             Tanya M               5
# 9            873             0             Diana S               3
# 10           873             1              Adam P               0
# 11           873             2             Thaiahh               5
# 12           873             3             Kathy H               5
# 13           873             4       aprildoornbos               6
# 14           873             5           cmincalif               5
# 15           873             6       Christopher H               3
# 16           873             7             Dixie W               2
# 17           873             8             Malfer1               0
# 18           467             0            432geoff               5
# 19           467             1             Peter R               6
# 20           467             2     navintandon2016               5
# 21           467             3           Maurene_K               6
# 22           467             4           AndyB5542               6
# 23           467             5           Chelsey W               5
# 24           467             6           ccindyk48               6
# 25           467             7         Catherine C               6
# 26           467             8        HelenaGuerra               6
# 27           467             9             David I               5
# 28           467            10           RideMaine               4
# 29           926             0             Ernie B               5
# ...          ...           ...                 ...             ...
# 1297776        0         48045             unknown               0
# 1297777        0         48046              nipon4               5
# 1297778        0         48047         Pinkcustard               4
# 1297779        0         48048          scobnurse1               3
# 1297780        0         48049               Kalle               4
# 1297781        0         48050            Nicci_UK               5
# 1297782        0         48051               caron               5
# 1297783        0         48052         DukeofMilan               4
# 1297784        0         48053             sjh2005               1
# 1297785        0         48054     Montreal_native               6
# 1297786        0         48055              spatan               6
# 1297787        0         48056        questioner29               2
# 1297788        0         48057              LAGirl               4
# 1297789        0         48058          mstamigirl               3
# 1297790        0         48059             unknown               0
# 1297791        0         48060         shellie2004               4
# 1297792        0         48061             unknown               0
# 1297793        0         48062             unknown               0
# 1297794        0         48063              sports               4
# 1297795        0         48064             unknown               0
# 1297796        0         48065             unknown               0
# 1297797        0         48066             unknown               0
# 1297798        0         48067      CallawayDenver               3
# 1297799        0         48068             unknown               0
# 1297800        0         48069          lovlilynne               4
# 1297801        0         48070            Bellgill               1
# 1297802        0         48071             unknown               0
# 1297803        0         48072         jtbroderick               4
# 1297804        0         48073             unknown               0
# 1297805        0         48074             unknown               0
#
#                date  stars                                              title  \
# 0        2015-09-26      3           helpful with your utah vacation planning
# 1        2013-10-14      5                              shame on us americans
# 2        2013-10-10      3                              beautiful but crowded
# 3        2013-09-19      5                              wow zion is beautiful
# 4        2013-08-29      5                   zion national park does it right
# 5        2012-09-29      4                                     beautiful park
# 6        2012-05-21      4                            utah travel information
# 7        2012-04-07      5                             utah39s national parks
# 8        2011-12-22      5                                utah travel council
# 9        2015-05-19      5                                a learned adventure
# 10       2015-01-29      5                                       dont miss it
# 11       2013-06-12      5                          joshua tree national park
# 12       2012-10-21      4                         joshua tree retreat center
# 13       2012-09-12      5                          joshua tree national park
# 14       2012-04-03      5  absolutely beautiful place to take pictures an...
# 15       2012-02-22      4                                like another planet
# 16       2012-02-07      5                                        go trekking
# 17       2011-12-29      5                             something for everyone
# 18       2016-11-02      4                        a great welcome to the park
# 19       2016-09-15      5  stop in to collect one of 12 park stamps avail...
# 20       2016-09-06      5  all the facilities and information minus the q...
# 21       2016-07-18      4          an acadia national park pass sales office
# 22       2016-07-09      3                                          easy stop
# 23       2015-09-20      5                                greatest adventure
# 24       2015-08-27      3                                       sunday blues
# 25       2015-07-24      4  very helpful staff  especially useful with fin...
# 26       2014-06-02      4                        good place to get some info
# 27       2013-09-02      5                                     volunteers tip
# 28       2012-08-29      5                     one stop mt desert island info
# 29       2016-11-07      5                absolutely the best park experience
# ...             ...    ...                                                ...
# 1297776  2005-10-08      5   what would new york city be without central park
# 1297777  2005-08-22      3                 nothing special just a quiet place
# 1297778  2005-07-19      5              amazing  best park i39ve ever been to
# 1297779  2005-07-16      5                                they do have trees
# 1297780  2005-07-16      5                                   mustsee number 1
# 1297781  2005-05-11      5                                      amazing place
# 1297782  2005-04-26      5  now i see why this is one of the most visited ...
# 1297783  2005-04-01      5                   central park  a must visit place
# 1297784  2005-03-26      5                                         a must see
# 1297785  2005-03-03      5                                             a must
# 1297786  2005-03-02      5                         did i have a saffron dream
# 1297787  2005-01-16      5                                        just wander
# 1297788  2005-01-08      4                         a beautiful place to visit
# 1297789  2004-12-07      5                                    an amazing ride
# 1297790  2004-12-05      5                    the most amazing place on earth
# 1297791  2004-12-05      5                                 most amazing place
# 1297792  2004-10-20      5                         central park in the winter
# 1297793  2004-09-13      5                            my grandchildren summer
# 1297794  2004-09-12      5                                    heaven on earth
# 1297795  2004-08-08      5                                       central park
# 1297796  2004-07-05      5                              we loved central park
# 1297797  2004-06-19      5                          central park a nice break
# 1297798  2004-06-04      4                                          beautiful
# 1297799  2004-05-19      5                         central park walking tours
# 1297800  2004-04-22      2                                   not for visitors
# 1297801  2004-03-02      5                                            magical
# 1297802  2004-01-12      5                             return to central park
# 1297803  2003-10-08      5                                  autum in new tork
# 1297804  2003-08-24      5      best park in the world best city in the world
# 1297805  2003-06-07      5                           a little piece of heaven
#
#                                                   comments
# 0        helpful with your utah vacation planning   uta...
# 1        shame on us americans   recently i and my wife...
# 2        beautiful but crowded   zion is beautiful but ...
# 3        wow zion is beautiful   this was our first vis...
# 4        zion national park does it right   first the s...
# 5        beautiful park   this park is so beautiful we ...
# 6        utah travel information   a great resource you...
# 7        utah39s national parks   what a lucky state to...
# 8        utah travel council   the utah travel council ...
# 9        a learned adventure   the desert institute is ...
# 10       dont miss it   i think that many folks drive r...
# 11       joshua tree national park   a week pass for th...
# 12       joshua tree retreat center   this retreat cent...
# 13       joshua tree national park   i went there with ...
# 14       absolutely beautiful place to take pictures an...
# 15       like another planet   huge park we hired a gui...
# 16       go trekking   so quiet and peacefulbring your ...
# 17       something for everyone   we spent a day at the...
# 18       a great welcome to the park   the staff were f...
# 19       stop in to collect one of 12 park stamps avail...
# 20       all the facilities and information minus the q...
# 21       an acadia national park pass sales office   th...
# 22       easy stop   this vic is right off the road to ...
# 23       greatest adventure    we had a great stop here...
# 24       sunday blues   we rolled in on a sunday amp be...
# 25       very helpful staff  especially useful with fin...
# 26       good place to get some info   this is the firs...
# 27       volunteers tip   we want to thank the lady tha...
# 28       one stop mt desert island info   acadia nation...
# 29       absolutely the best park experience   island d...
# ...                                                    ...
# 1297776  what would new york city be without central pa...
# 1297777  nothing special just a quiet place   after hea...
# 1297778  amazing  best park i39ve ever been to   centra...
# 1297779  they do have trees    this was my first trip t...
# 1297780  mustsee number 1   as i first came to central ...
# 1297781  amazing place   wow what a place i really didn...
# 1297782  now i see why this is one of the most visited ...
# 1297783  central park  a must visit place   everything ...
# 1297784  a must see   we visited central park in march ...
# 1297785  a must   central park was great we were there ...
# 1297786  did i have a saffron dream   we wandered from ...
# 1297787  just wander   one of the world39s greatest urb...
# 1297788  a beautiful place to visit   we visited ny in ...
# 1297789  an amazing ride   you have to experience centr...
# 1297790  the most amazing place on earth   everyone has...
# 1297791  most amazing place   yes this is the most amaz...
# 1297792  central park in the winter   we travelled to n...
# 1297793  my grandchildren summer   central park was the...
# 1297794  heaven on earth   central park is like no othe...
# 1297795  central park   if you are planning a trip to m...
# 1297796  we loved central park   central park at first ...
# 1297797  central park a nice break   central park was a...
# 1297798  beautiful   lovely place to visit you need to ...
# 1297799  central park walking tours   central park can ...
# 1297800  not for visitors   we stayed at the sheraton m...
# 1297801  magical   to arrive at central park to the sce...
# 1297802  return to central park   every time i return t...
# 1297803  autum in new tork   we took our 5yr old on a 4...
# 1297804  best park in the world best city in the world ...
# 1297805  a little piece of heaven   having been to new ...
#
# [1297575 rows x 8 columns]

# %% [markdown]
# ###### 3. Processing review data for modeling
# * 3.1 Concatenate reviews for the same park
# * 3.2 Joint two dataframes for combined comments and visit type information

# %%
def concat(df):
    return pd.Series(dict(park_id=int(df['park_id'].mean()),
                          stars=df['stars'].mean(),
                          comments=' '.join(df['comments'])))
    
review_grouped_df = review_df.groupby('park_id',as_index=False).apply(concat)

merge_col = ['park_id', 'name', 'state','Families', 'Couples', 'Friends', 'Solo', 'Business', 'Spring',
             'Summer', 'Fall', 'Winter','total_visit']
park_groups_df = pd.merge(review_grouped_df, parks_df[merge_col], on='park_id')
park_groups_df.head()
# Out:
#                                             comments  park_id     stars  \
# 0  great place to see what39s going on in nyc   g...        0  4.730393
# 1  well worth our time   beautiful drive and we h...        1  4.350000
# 2  amazing   nature is truly awesome there is gre...        2  4.733186
# 3  some of the best snorkeling ever   we took the...        3  4.765029
# 4  this is the most spectacular area i visited in...        4  4.896316
#
#                              name     state  Families  Couples  Friends  \
# 0                    Central Park  New York   12377.0  15311.0   7739.0
# 1       Hot Springs National Park  Arkansas      95.0    151.0     46.0
# 2  Hawaii Volcanoes National Park    Hawaii    1168.0   1875.0    481.0
# 3      Dry Tortugas National Park   Florida     694.0   1561.0    478.0
# 4                    Bryce Canyon      Utah     815.0   1636.0    469.0
#
#      Solo  Business   Spring   Summer     Fall  Winter  total_visit
# 0  2824.0    1144.0  11247.0  14390.0  11419.0  9064.0      46120.0
# 1    15.0       6.0    104.0    143.0     78.0    44.0        369.0
# 2   161.0      19.0   1150.0   1220.0    860.0  1136.0       4366.0
# 3   112.0      17.0    825.0    932.0    575.0   692.0       3024.0
# 4   144.0       8.0    783.0   1473.0   1100.0   305.0       3661.0

# %% [markdown]
# ###### 4. Sentiment analysis with KMeans
# * clustering parks based on the aggregated comments

# %% [markdown]
# * 4.1 Build Pipeline
# * 4.2 Build parameter optimization grid

# %%
pipeline = Pipeline([('vect', TfidfVectorizer(strip_accents='unicode',
                                              max_df = 0.5,
                                              token_pattern = r'\b\w+\b',
                                              ngram_range=(1,1), 
                                              stop_words='english')),
                     ('svd', TruncatedSVD()),
                     ('norm', Normalizer(copy=False)),
                     ('kmeans', KMeans())])

param_grid = {'vect__min_df': [1],
              'svd__n_components': [300,500],
              'kmeans__n_clusters': [10,15]}

search_grid = GridSearchCV(estimator=pipeline, 
                           param_grid=param_grid, 
                           verbose=1,
                           refit=True)

if FIT_SWITCH:
    search_grid.fit(park_groups_df['comments'])
    best_estimator = search_grid.best_estimator_
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 29.7min finished

# %% [markdown]
# * 4.3 Save the best model or load fitted model from local

# %%
model_file_name = os.path.join(MODEL_FOLDER,'kmeans_model.pkl')
grid_file_name = os.path.join(MODEL_FOLDER,'kmeans_grid.pkl')
if FIT_SWITCH:
    joblib.dump(search_grid.best_estimator_, model_file_name)
    joblib.dump(search_grid.grid_scores_, grid_file_name)
    best_estimator = search_grid.best_estimator_
    grid_score = search_grid.grid_scores_
else:
    best_estimator = joblib.load(model_file_name)
    grid_score = joblib.load(grid_file_name)
    
fitted_vects = best_estimator.named_steps['vect'].transform(park_groups_df['comments']) #tfidf sparse matrix
fitted_svds = best_estimator.named_steps['svd'].transform(fitted_vects) #reduced dimension of tfidf

# %%
'''get cluster assignments'''
cluster_assignment = best_estimator.named_steps['kmeans'].labels_
variance_explained=best_estimator.named_steps['svd'].explained_variance_ratio_.sum()
print 'variance_explained is %f.' %variance_explained
# Out:
# variance_explained is 0.730947.

# %% [markdown]
# ###### 5. Visualization of clusters
# * 5.1 parks clusters
# * 5.2 key words in clusters

# %% [markdown]
# * 5.1.1 reduce to 3d space
# * 5.1.2 plot park clusters in 3d

# %%
reduce_model = TSNE(n_components=3, random_state=0)
pos = reduce_model.fit_transform(fitted_svds)

# %%
cluster_n = len(set(cluster_assignment)) # number of clusters
def plot_projection(data, cluster_assignment, cluster_n):
    alpha = 0.7
    size = 15
    fig = plt.figure(figsize=(size, size * 0.8))
    ax = fig.add_subplot(111, projection='3d')
    xpos, ypos, zpos = zip(*data[:, 0:3])
    color_list = [plt.get_cmap('jet')(int(i)) for i in np.linspace(0, 256, cluster_n)]
    color_list = random.sample(color_list, len(color_list))
    colors = [color_list[i] * np.array([1, 1, 1, alpha]) for i in cluster_assignment]
    ax.scatter(xpos, ypos, zpos, marker='o', c=colors, s=size*3, linewidth=0)

plot_projection(pos, cluster_assignment, cluster_n)

# %% [markdown]
# * 5.2.1 Extract clustering keywords

# %%
cluster_centers = best_estimator.named_steps['kmeans'].cluster_centers_
original_space_centroids = best_estimator.named_steps['svd'].inverse_transform(cluster_centers)
order_centroids = original_space_centroids.argsort()[:,::-1]
feature_words = best_estimator.named_steps['vect'].get_feature_names()
feature_dict = dict()
words_n = 30 # get top 30 words
for i, cluster in enumerate(original_space_centroids):
    feature_dict[i] = [feature_words[j] for (count, j) in enumerate(order_centroids[i]) if count < words_n]

# %%
pd.set_option('display.max_colwidth',-1)
pd.Series(feature_dict)
# Out:
# 0     [canyon, zion, bryce, rim, vegas, utah, shuttle, narrows, formations, las, canyons, monument, tunnel, hoodoos, cedar, kings, elena, santa, kaibab, kolob, eldorado, bend, navajo, dam, rio, landing, colorado, desert, angel39s, angel]
# 1     [boat, everglades, alligators, island, rainier, snorkeling, springs, gators, captain, biscayne, florida, glacier, airboat, refuge, snorkel, islands, paradise, liberty, flamingo, manatees, fish, beach, kayak, cruise, turtles, alligator, ferry, boardwalk, statue, swamp]
# 2     [monument, cave, petrified, ruins, campground, dunes, bridge, desert, dc, falls, washington, creek, lincoln, dwellings, olympic, canyon, canal, gatlinburg, springs, mesa, cliff, verde, gorge, tickets, exhibit, war, president, sand, buildings, waterfalls]
# 3     [falls, waterfall, waterfalls, niagara, gorge, yosemite, bridge, creek, potomac, mist, swimming, canyon, sioux, burney, paterson, maid, upper, turner, vernal, minnehaha, alberta, greenville, havasupai, akaka, silver, brandywine, duc, letchworth, bridalveil, canadian]
# 4     [yellowstone, teton, faithful, tetons, geysers, geyser, bison, jackson, elk, moose, basin, springs, canyon, buffalo, falls, matt, mammoth, thermal, lamar, grizzly, hole, lodge, prismatic, biscuit, bear, boardwalk, jenny, pools, village, safari]
# 5     [battlefield, war, battle, civil, cemetery, gettysburg, vicksburg, battlefields, battles, soldiers, military, revolutionary, fought, shiloh, monuments, union, chattanooga, chickamauga, richmond, buff, confederate, monument, cairo, graves, antietam, 1812, cyclorama, cd, cannons, buffs]
# 6     [lava, volcano, crater, volcanoes, island, rim, kilauea, hilo, hawaii, tube, josh, volcanic, craters, hawaiian, glow, kona, flow, caldera, haleakala, warren, sunrise, ricky, caves, steam, volcanos, cruise, hank, vents, tubes, gil]
# 7     [beach, beaches, sand, lighthouse, ocean, seashore, dunes, cape, island, refuge, waves, bay, fishing, sea, coast, sandy, shells, shore, swimming, tide, seals, campground, ferry, surf, fort, erie, gulf, showers, ponies, fish]
# 8     [fort, tortugas, war, boat, ferry, buildings, snorkeling, jefferson, lewis, augustine, clark, seaplane, vancouver, yankee, island, civil, sumter, french, forts, ft, caroline, revolutionary, colony, key, st, beach, pickens, washington, restored, freedom]
# 9     [arch, arches, canyonlands, moab, canyon, needles, navtec, delicate, furnace, fiery, rafting, double, utah, mesa, colorado, horse, canyons, formations, 4x4, dead, island, balanced, jeep, courthouse, monument, shafer, potash, bridges, avenue, chesler]
# 10    [joshua, rides, zoo, san, gardens, art, garden, desert, diego, coasters, roller, disney, amusement, pier, cactus, saguaro, seaworld, coaster, lines, chicago, juan, theme, palm, museums, ships, oasis, universal, busch, safari, sea]
# 11    [denali, estes, badlands, rmnp, rocky, moose, bison, denver, bear, elk, horses, caribou, buffalo, driver, prairie, sheep, shuttle, mckinley, ridge, alaska, dakota, tundra, moraine, mt, colorado, kantishna, alpine, eielson, nymph, unit]
# 12    [stadium, baseball, game, ballpark, seats, ball, field, league, games, nationals, fans, team, braves, seat, fan, tickets, mlb, fenway, ballparks, wrigley, phillies, beer, stadiums, mets, ballgame, minor, prices, pnc, venue, camden]
# 13    [acadia, cadillac, harbor, bar, carriage, ocean, island, thunder, maine, schoodic, jordan, beach, otter, pond, gorham, sand, hole, beehive, tide, bikes, cliffs, rungs, precipice, cruise, desert, woody, driver, mdi, coast, heights]
# 14    [yosemite, glacier, sequoia, dome, sherman, sequoias, giant, muir, village, glaciers, rafting, grove, capitan, tioga, falls, driver, lodge, kings, francisco, san, tunnel, el, meadows, bear, mcdonald, tuolumne, boat, logan, apgar, shuttle]
# dtype: object

# %% [markdown]
# * 5.2.2 Visualization keywords clustering

# %%
def cluster_radius(cluster):
    '''calculate the radius of one cluster'''
    max_r = max([len(v) for (k, v) in cluster.items()])
    return int(ceil(max_r ** (1/3.0)))

def assign_cords(points, origin=np.zeros(3), radius=1):
    '''calculate'''
    l = len(points)
    d = int(ceil(l ** (1/3.0)))
    pos = zip([i + origin for i in product(np.array(range(d)) * radius, repeat=3)], points)
    return [pos[int(i)] for i in np.linspace(0, len(pos)-1, l)]

def assign_colors(clusters):
    if isinstance(clusters, (int, float)):
        l = int(clusters)
    else:
        l = len(clusters) + 1
    color_list = [plt.get_cmap('jet')(int(i)) for i in np.linspace(0, 256, l)]
    return random.sample(color_list, len(color_list))

def cluster_cords(clusters):
    cluster_r = cluster_radius(clusters) + 1
    cords = dict()
    cluster_centers = assign_cords(clusters.keys(), np.zeros(3), cluster_r)
    colors = assign_colors(clusters)
    for (cluster_name, one_cluster, one_center, onecolor) in zip(clusters.keys(), clusters.values(), cluster_centers, colors):
        cluster_cords = [(i[1], i[0], onecolor) for i in assign_cords(one_cluster, one_center[0], 1)]
        cords[cluster_name] = cluster_cords
    return cords


''' cluster_structure
    [cluster1: [(word1, (x, y, z), (r, g, b)),
                (word2, (x, y, z), (r, g, b)),
                (word3, (x, y, z), (r, g, b)),
                (word4, (x, y, z), (r, g, b))]
     cluster2: [(word1, (x, y, z), (r, g, b)),
                (word2, (x, y, z), (r, g, b)),
                (word3, (x, y, z), (r, g, b)),
                (word4, (x, y, z), (r, g, b))]
     cluster3: [(word1, (x, y, z), (r, g, b)),
                (word2, (x, y, z), (r, g, b)),
                (word3, (x, y, z), (r, g, b)),
                (word4, (x, y, z), (r, g, b))] 
    ]
'''

def adjust_cords(cords):
    cal_cords = {}
    new_cords = {}
    for one_cluster in cords.values():
        for one_point in one_cluster:
            try:
                cal_cords[one_point[0]].append((one_point[1], one_point[2]))
            except KeyError:
                cal_cords[one_point[0]] = [(one_point[1], one_point[2])]
   
    for point_key, one_point in cal_cords.items():
        new_point = zip(*one_point)
        new_cord = np.mean(np.vstack(new_point[0]), axis=0)
        new_color = np.mean(np.vstack(new_point[1]), axis=0)
        new_cords[point_key] = (new_cord, new_color)
    return new_cords

'''
['word1': ((x, y, z) of word1 in cluster a, (x, y, z) of word1 in cluster b), 
          ((r, g, b) of word1 in cluster a, (r, g, b) of word1 in cluster b),
 'word2': ((x, y, z) of word2 in cluster a),(x, y, z) of word2 in cluster b)
          ((r, g, b) of word2 in cluster a),(r, g, b) of word2 in cluster b)
          ...]
'''


'''
['word1': average((x, y, z) of word1), average((r, g, b) of word1),
 'word2': average((x, y, z) of word2), average((r, g, b) of word2),
 'word3': average((x, y, z) of word3), average((r, g, b) of word3),
 'word4': average((x, y, z) of word4), average((r, g, b) of word4)]
'''

def draw_cords(cords):
    size = 20
    plot_range = np.max(np.vstack([i[0] for i in cords.values()]), axis=0) + np.ones(3)
    fig = plt.figure(figsize=(size, size * 0.8))
    ax = fig.add_subplot(111, projection='3d')
    for one_key, one_point in cords.items():
        ax.text(one_point[0][0], one_point[0][1], one_point[0][2] , one_key, color=one_point[1], size=size*0.6)
        #ax.scatter(one_point[0][0], one_point[0][1], one_point[0][2] , one_key, color=one_point[1])
    ax.set_xlim([-1, plot_range[0]])
    ax.set_ylim([-1, plot_range[1]])
    ax.set_zlim([-1, plot_range[2]])
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_zticks([])
    fig.show()


test_cords = cluster_cords(feature_dict)
#print 'test_cords', test_cords
new_cords = adjust_cords(test_cords)
#print 'new_cords',new_cords
draw_cords(new_cords)

# %% [markdown]
# ###### 6 Query similar parks
# * 6.1 Retrieve cluster members
# * 6.1.1 Find words with top 30 tf-idf score for each park

# %%
park_groups_df['cluster_assignment'] = pd.Series(cluster_assignment, index=park_groups_df.index)
park_groups_df['cluster_assignment'].value_counts()
# Out:
# 2     400
# 10    83
# 1     71
# 0     67
# 11    62
# 7     43
# 5     42
# 14    41
# 4     41
# 6     38
# 9     32
# 3     30
# 8     29
# 13    27
# 12    19
# Name: cluster_assignment, dtype: int64

# %%
vocabulary = best_estimator.named_steps['vect'].get_feature_names()
park_features=[]
for ind in park_groups_df.index:
    park_x = fitted_vects[ind]
    park_features.append([y[0] for y in sorted(zip(vocabulary, park_x.todense().A1), 
                                               key=lambda x:x[1],reverse=True)[0:20]])
park_groups_df['park_features']= pd.Series(park_features,index=park_groups_df.index)



park_assignment_df = park_groups_df[['park_id','cluster_assignment','park_features']]
park_assignment_df.to_csv(os.path.join(DATA_FOLDER,'park_assignment.csv'))

# %%
'''save the result to csv'''
if SAVE_SWITCH == True:
    park_assignment_df = park_groups_df[['park_id','cluster_assignment','park_features']]
    park_assignment_df.to_csv(os.path.join(DATA_FOLDER,'park_assignment.csv'))

# %% [markdown]
# * 6.1.2 Retrieve parks using cluster label

# %%
pd.set_option('display.max_colwidth',-1)
query_cluster = 2
season = 'Winter'
visit_type = 'Families'
cluster_name = 'cluster'+'_'+str(query_cluster)
cluster_name = (park_groups_df[park_groups_df['cluster_assignment']==query_cluster]
                .sort_values([season,'stars','total_visit',visit_type],ascending=False)
               [['park_id','name','state','stars',season,visit_type,'total_visit','park_features','cluster_assignment']])
cluster_name.head(30)
# Out:
#       park_id                                                       name  \
# 0     0        Central Park
# 879   896      Top of the Rock Observation Deck
# 872   889      The High Line
# 915   935      USS Arizona Memorial
# 870   887      Golden Gate Bridge
# 1020  1043     The National WWII Museum
# 25    25       Epcot
# 948   968      Kennedy Space Center Visitor Complex
# 563   573      Lincoln Memorial Reflecting Pool
# 329   336      Bryant Park
# 196   200      Jackson Square
# 722   734      Epcot World Showcase
# 809   824      Discovery Cove
# 638   648      Pearl Harbor WW II Valor in the Pacific National Monument
# 627   637      La Jolla Cove
# 290   296      Smithsonian National Museum of Natural History
# 84    85       Garden of the Gods
# 159   162      Banyan Tree Park
# 777   789      New York Public Library
# 509   518      Forsyth Park
# 793   806      Hoover Dam Bypass
# 277   282      Independence Hall
# 625   635      Cathedral Rock
# 314   320      Blue Ridge Parkway
# 939   959      Hershey s Chocolate World
# 512   521      National World War II Memorial
# 57    57       Muir Woods National Monument
# 581   591      The Houston Museum of Natural Science
# 456   464      Washington Monument
# 544   554      Charleston Waterfront Park
#
#                state     stars  Winter  Families  total_visit  \
# 0     New York        4.730393  9064.0  12377.0   46120.0
# 879   New York        4.666469  7022.0  8699.0    32569.0
# 872   New York        4.589806  3936.0  5006.0    24061.0
# 915   Hawaii          4.740131  3326.0  4351.0    15247.0
# 870   California      4.695005  3317.0  4880.0    20875.0
# 1020  Louisiana       4.767768  3300.0  3003.0    15296.0
# 25    Florida         4.301735  2526.0  4770.0    10993.0
# 948   Florida         4.574488  2311.0  3731.0    9359.0
# 563   Washington DC   4.759264  2015.0  4604.0    14106.0
# 329   New York        4.593328  1978.0  1750.0    7323.0
# 196   Louisiana       4.520005  1850.0  1615.0    8524.0
# 722   Florida         4.507170  1625.0  4068.0    8250.0
# 809   Florida         4.804927  1587.0  5526.0    10313.0
# 638   Hawaii          4.736278  1585.0  1904.0    7301.0
# 627   California      4.586538  1162.0  1973.0    5892.0
# 290   Washington DC   4.526379  982.0   2567.0    6459.0
# 84    Colorado        4.777681  958.0   3496.0    10008.0
# 159   Hawaii          4.405793  953.0   1104.0    3851.0
# 777   New York        4.576798  878.0   1072.0    4445.0
# 509   Georgia         4.659876  810.0   1103.0    4867.0
# 793   Nevada          4.520833  741.0   956.0     4340.0
# 277   Pennsylvania    4.577029  726.0   1575.0    4922.0
# 625   Arizona         4.828164  675.0   727.0     3519.0
# 314   North Carolina  4.812257  671.0   1078.0    5637.0
# 939   Pennsylvania    4.184264  658.0   2689.0    5278.0
# 512   Washington DC   4.691566  648.0   1714.0    5201.0
# 57    California      4.718451  600.0   1059.0    3949.0
# 581   Texas           4.623468  598.0   1144.0    2774.0
# 456   Washington DC   4.521667  575.0   1200.0    4003.0
# 544   South Carolina  4.613326  515.0   924.0     3780.0
#
#                                                                                                                                                                                                           park_features  \
# 0     [central, nyc, york, carriage, strawberry, horse, zoo, lennon, manhattan, oasis, skating, boathouse, ny, fields, bikes, rink, bustle, hustle, belvedere, bethesda]
# 879   [empire, nyc, york, manhattan, central, esb, observation, rockefeller, deck, tickets, elevator, queues, skyline, queue, ny, ticket, lift, totr, lines, glass]
# 872   [chelsea, nyc, highline, york, elevated, railway, manhattan, market, meatpacking, hudson, streets, disused, urban, rail, district, art, ny, 34th, plants, whitney]
# 915   [arizona, pearl, uss, harbor, tickets, oahu, honolulu, harbour, boat, hawaii, emotional, missouri, ship, attack, somber, bowfin, oil, war, solemn, tribute]
# 870   [bridge, golden, francisco, san, gate, sausalito, sf, fog, bay, iconic, alcatraz, marin, ferry, wharf, bikes, fran, cycle, engineering, foggy, hop]
# 1020  [wwii, war, hanks, orleans, 4d, tom, nola, boundariesquot, quotbeyond, boundaries, ww2, ii, submarine, interactive, dday, pacific, museums, veterans, narrated, planes]
# 25    [epcot, disney, rides, countries, showcase, soarin, test, soarin39, festival, wine, track, kingdom, spaceship, fireworks, mission, nemo, orlando, theme, magic, flower]
# 948   [atlantis, kennedy, ksc, launch, shuttle, rocket, astronaut, imax, rockets, saturn, nasa, orlando, apollo, exhibit, simulator, complex, pads, florida, v, astronauts]
# 563   [lincoln, dc, reflecting, pool, monument, washington, statue, mall, steps, memorials, lincoln39s, president, monuments, speech, luther, abe, capitol, martin, speeches, abraham]
# 329   [bryant, skating, rink, library, nyc, christmas, york, shops, midtown, oasis, manhattan, market, skate, coffee, carousel, stalls, chess, square, ny, skaters]
# 196   [square, jackson, orleans, artists, cathedral, french, monde, musicians, performers, quarter, du, nola, music, art, louis, cafe, tarot, carriage, beignets, st]
# 722   [epcot, countries, disney, showcase, wine, festival, rides, fireworks, france, norway, soarin, mexico, japan, cultures, china, germany, morocco, foods, test, kingdom]
# 809   [dolphin, cove, dolphins, discovery, swim, orlando, swimming, reef, rays, inclusive, snorkeling, breakfast, fish, aquatica, lazy, drinks, expensive, aviary, seaworld, snorkel]
# 638   [pearl, harbor, arizona, uss, harbour, oahu, missouri, bowfin, honolulu, tickets, hawaii, submarine, battleship, emotional, boat, attack, war, audio, wwii, monument]
# 627   [seals, jolla, lions, cove, sea, la, beach, diego, san, ocean, snorkeling, seal, waves, smell, pelicans, swimming, swim, snorkel, beaches, restaurants]
# 290   [diamond, smithsonian, exhibit, dc, dinosaurs, museums, butterfly, dinosaur, gems, minerals, imax, mummies, mammals, evolution, collection, fossils, butterflies, washington, bones, elephant]
# 84    [gods, garden, formations, colorado, springs, trading, pikes, climbers, manitou, post, gog, camels, horseback, kissing, balanced, siamese, pike39s, balancing, denver, formation]
# 159   [banyan, lahaina, maui, courthouse, homeless, branches, art, block, banyon, artists, crafts, craft, shopping, roots, trunks, shops, benches, vendors, market, selling]
# 777   [library, architecture, bryant, york, nyc, books, lions, pooh, libraries, rooms, nypl, winnie, ny, ceilings, marble, exhibit, children39s, ghostbusters, exhibition, gutenberg]
# 509   [forsyth, savannah, fountain, moss, squares, market, spanish, cafe, oaks, farmers, playground, fountains, district, farmer39s, savannah39s, oak, playgrounds, homes, playing, forsythe]
# 793   [dam, hoover, vegas, bridge, bypass, engineering, las, canyon, mead, nevada, arizona, marvel, tillman, feat, structure, damn, strip, construction, helicopter, power]
# 277   [independence, hall, bell, liberty, tickets, philadelphia, declaration, philly, constitution, ticket, founding, security, fathers, timed, birthplace, signed, nation, online, congress, rooms]
# 625   [sedona, cathedral, vortex, creek, templeton, oak, formation, baldwin, saddle, crossing, formations, crescent, scramble, 179, energy, moon, strenuous, bell, verde, scrambling]
# 314   [parkway, asheville, ridge, brp, mitchell, nc, pisgah, overlooks, cherokee, carolina, craggy, linville, mt, leaves, speed, boone, ashville, motorcycle, virginia, waterfalls]
# 939   [chocolate, hershey, candy, hershey39s, factory, bar, 4d, trolley, tasting, chocolates, cows, bars, court, hersheys, process, milton, 3d, cute, singing, products]
# 512   [wwii, war, monument, tribute, lincoln, memorials, dc, ii, washington, fountains, mall, veterans, fought, fountain, served, pool, pacific, honor, generation, reflecting]
# 57    [muir, woods, redwoods, francisco, san, redwood, sausalito, sf, giant, majestic, golden, bridge, shuttle, gate, fran, boardwalk, tall, monument, bay, giants]
# 581   [soonspan, exhibit, houston, butterfly, feedback, patrons, classpartialentryspan, dinosaur, dinosaurs, hmns, paleontology, planetarium, science, imax, hall, egyptian, egypt, collection, butterflies, permanent]
# 456   [monument, washington, dc, tickets, mall, elevator, lincoln, earthquake, ticket, obelisk, online, monuments, advance, capitol, scaffolding, iconic, structure, tall, flags, landmark]
# 544   [charleston, waterfront, swings, fountain, fountains, pier, pineapple, harbor, sumter, dolphins, benches, swing, ravenel, ships, breeze, bridge, fort, battery, boats, yorktown]
#
#       cluster_assignment
# 0     2
# 879   2
# 872   2
# 915   2
# 870   2
# 1020  2
# 25    2
# 948   2
# 563   2
# 329   2
# 196   2
# 722   2
# 809   2
# 638   2
# 627   2
# 290   2
# 84    2
# 159   2
# 777   2
# 509   2
# 793   2
# 277   2
# 625   2
# 314   2
# 939   2
# 512   2
# 57    2
# 581   2
# 456   2
# 544   2

# %% [markdown]
# * 6.1.3 Query similar parks

# %%
the_park = park_groups_df[park_groups_df['name'].str.contains("Magic Kingdom")][['park_id','name','state','total_visit','cluster_assignment','park_features']]
the_park
# Out:
#     park_id           name    state  total_visit  cluster_assignment  \
# 39  39       Magic Kingdom  Florida  26005.0      10
#
#                                                                                                                                                                          park_features
# 39  [kingdom, magic, disney, rides, fireworks, parade, castle, parades, lines, characters, mk, fastpass, orlando, fantasyland, passes, mickey, happiest, christmas, theme, princesses]

# %%
pd.set_option('display.max_colwidth',-1)
query_cluster =park_groups_df.loc[the_park['park_id']]['cluster_assignment']
season = 'Winter'
visit_type = 'Families'
cluster_name = 'cluster'+'_'+str(query_cluster)
cluster_name = (park_groups_df[park_groups_df['cluster_assignment']==query_cluster.values[0]]
                .sort_values([season,'stars','total_visit',visit_type],ascending=False)
               [['park_id','name','state','stars',season,visit_type,'total_visit','park_features']])
cluster_name.head(30)
# Out:
#      park_id                                    name          state     stars  \
# 39   39       Magic Kingdom                           Florida        4.409196
# 647  658      The Metropolitan Museum of Art          New York       4.793119
# 285  291      San Diego Zoo                           California     4.597772
# 362  370      Disney s Animal Kingdom                 Florida        4.402896
# 400  408      SeaWorld Orlando                        Florida        4.299315
# 289  295      Universal Studios Hollywood             California     4.382636
# 519  528      Disney s Hollywood Studios              Florida        4.230037
# 972  992      The Art Institute of Chicago            Illinois       4.806120
# 448  456      Disney California Adventure Park        California     4.522870
# 473  481      Busch Gardens Tampa                     Florida        4.282459
# 275  280      Millennium Park                         Illinois       4.656340
# 5    5        Balboa Park                             California     4.704793
# 385  393      Dollywood                               Tennessee      4.387570
# 551  561      Santa Monica Pier                       California     4.057249
# 818  833      SeaWorld San Diego                      California     4.225402
# 457  465      LEGOLAND Florida Resort                 Florida        3.898319
# 682  694      National Gallery of Art                 Washington DC  4.776727
# 315  321      Golden Gate Park                        California     4.581298
# 712  724      Silver Dollar City                      Missouri       4.467732
# 474  482      Busch Gardens Williamsburg              Virginia       4.409188
# 29   29       Cabrillo National Monument              California     4.607019
# 469  477      New Orleans City Park                   Louisiana      4.623557
# 562  572      St Louis Zoo                            Missouri       4.719554
# 482  490      Old Town San Diego State Historic Park  California     4.279312
# 960  980      Atlanta Botanical Garden                Georgia        4.623564
# 767  779      Knott s Berry Farm                      California     4.112324
# 98   100      San Diego Zoo Safari Park               California     4.471247
# 944  964      Universal CityWalk                      Florida        4.214984
# 890  909      Lincoln Park Zoo                        Illinois       4.475860
# 11   11       Hersheypark                             Pennsylvania   4.306291
#
#      Winter  Families  total_visit  \
# 39   5692.0  15377.0   26005.0
# 647  4372.0  5123.0    21273.0
# 285  3068.0  5926.0    15764.0
# 362  3035.0  7578.0    13670.0
# 400  2844.0  7873.0    15264.0
# 289  2352.0  5276.0    13675.0
# 519  2202.0  6030.0    10728.0
# 972  2070.0  2780.0    13554.0
# 448  1805.0  4764.0    8459.0
# 473  1697.0  3917.0    8666.0
# 275  1461.0  3074.0    11793.0
# 5    1368.0  1652.0    6499.0
# 385  1199.0  5436.0    10594.0
# 551  1097.0  1947.0    6153.0
# 818  977.0   2823.0    5843.0
# 457  969.0   3333.0    4746.0
# 682  914.0   1385.0    5363.0
# 315  889.0   1358.0    5594.0
# 712  738.0   3347.0    6452.0
# 474  721.0   3372.0    5962.0
# 29   711.0   811.0     2803.0
# 469  632.0   651.0     2888.0
# 562  619.0   2749.0    5424.0
# 482  599.0   652.0     2664.0
# 960  582.0   767.0     2871.0
# 767  550.0   1371.0    2777.0
# 98   546.0   1013.0    2635.0
# 944  483.0   698.0     1805.0
# 890  476.0   1048.0    3192.0
# 11   409.0   3022.0    5156.0
#
#                                                                                                                                                                                                                          park_features
# 39   [kingdom, magic, disney, rides, fireworks, parade, castle, parades, lines, characters, mk, fastpass, orlando, fantasyland, passes, mickey, happiest, christmas, theme, princesses]
# 647  [art, egyptian, collection, nyc, museums, collections, paintings, york, metropolitan, exhibit, moma, louvre, gogh, wing, impressionist, galleries, armor, impressionists, exhibitions, greek]
# 285  [zoo, diego, san, pandas, zoos, panda, polar, enclosures, animal, koalas, tram, sd, bears, skyfari, zoo39s, safari, elephants, balboa, exhibit, habitats]
# 362  [safari, kingdom, everest, disney, animal, rides, lion, king, expedition, kilimanjaro, zoo, nemo, kali, africa, rapids, coaster, dinosaur, disney39s, roller, theme]
# 400  [seaworld, shamu, sea, rides, orlando, dolphin, manta, dolphins, coasters, roller, whale, whales, kraken, penguin, disney, penguins, killer, coaster, animal, atlantis]
# 289  [universal, studios, rides, studio, vip, potter, harry, transformers, hollywood, simpsons, mummy, jurassic, theme, la, 3d, waterworld, classpartialentryspan, lines, orlando, soonspan]
# 519  [disney, hollywood, studios, terror, rides, wars, toy, tower, coaster, star, roller, stunt, fantasmic, aerosmith, jones, mania, kingdom, indiana, magic, rollercoaster]
# 972  [art, institute, chicago, impressionist, collection, impressionists, paintings, gogh, collections, museums, monet, modern, exhibit, impressionism, wing, picasso, pieces, van, works, chagall]
# 448  [disneyland, california, disney, rides, radiator, racers, terror, carsland, springs, dca, hopper, screamin39, tower, fastpass, coaster, soarin39, screamin, toy, aladdin, lines]
# 473  [busch, rides, gardens, coasters, roller, cheetah, tampa, theme, orlando, coaster, sheikra, safari, disney, rollercoasters, animal, florida, zoo, amusement, montu, lines]
# 275  [bean, chicago, millennium, quotbeanquot, art, cloud, millenium, fountain, beanquot, concert, fountains, sculptures, concerts, sculpture, skating, gardens, gate, pritzker, institute, music]
# 5    [balboa, museums, diego, san, zoo, gardens, architecture, garden, organ, prado, botanical, art, buildings, japanese, spanish, science, rose, sd, restaurants, globe]
# 385  [dollywood, rides, coasters, dolly, roller, theme, amusement, christmas, coaster, lines, pigeon, eagle, forge, disney, gospel, music, train, parton, dolly39s, passes]
# 551  [pier, monica, santa, beach, rides, ferris, 66, wheel, amusement, ocean, bubba, restaurants, la, venice, shops, carnival, games, gump, coaster, roller]
# 818  [seaworld, shamu, sea, diego, dolphin, rides, san, whales, dolphins, whale, manta, killer, atlantis, orca, expensive, trainers, lion, orcas, lions, animal]
# 457  [legoland, lego, rides, florida, resortspan, legos, classpartialentryspan, regardskari, communicationslegoland, sguest, disney, coasters, orlando, soonkind, theme, roller, excellencelegoland, cypress, lines, jproduct]
# 682  [art, gallery, collection, paintings, dc, vinci, museums, impressionist, galleries, wing, collections, impressionists, degas, monet, works, sculpture, gogh, exhibit, da, masters]
# 315  [japanese, garden, tea, gardens, golden, gate, academy, francisco, san, conservatory, botanical, museums, sciences, sf, science, deyoung, haight, flowers, bridge, bison]
# 712  [sdc, silver, rides, dollar, branson, christmas, coasters, roller, theme, amusement, lights, outlaw, cave, crafts, lines, shops, coaster, entertainment, festival, tickets]
# 474  [busch, gardens, rides, coasters, bestryanspan, roller, williamsburg, classpartialentryspan, theme, amusement, christmas, coaster, lines, griffon, verbolten, soonall, howloscream, christmastown, bg, soonsincerelydestineespan]
# 29   [diego, cabrillo, san, lighthouse, monument, tide, loma, pools, coronado, ocean, bay, pacific, tidepools, harbor, naval, cemetery, military, rosecrans, tidal, downtown]
# 469  [sculpture, garden, orleans, beignets, art, botanical, nola, streetcar, oaks, gardens, storyland, cafe, oak, amusement, canal, sculptures, french, moss, katrina, noma]
# 562  [zoo, louis, st, zoos, train, penguin, polar, penguins, lion, exhibit, sea, stl, children39s, zoo39s, animal, bear, lions, carousel, elephants, habitats]
# 482  [diego, san, shops, mexican, restaurants, buildings, shopping, trolley, museums, stores, whaley, touristy, casa, california, reyes, tortillas, mexico, fargo, authentic, music]
# 960  [gardens, garden, atlanta, botanical, chihuly, lights, orchid, exhibit, orchids, christmas, piedmont, sculptures, glass, abg, plants, holiday, flowers, conservatory, munro, canopy]
# 767  [knott39s, knotts, rides, berry, farm, snoopy, coasters, roller, disneyland, theme, disney, lines, amusement, coaster, chicken, ghost, knott, thrill, kbf, tickets]
# 98   [safari, zoo, diego, san, tram, cheetah, animal, caravan, giraffes, african, rhinos, africa, escondido, enclosures, zoos, tiger, expensive, habitat, tigers, gorillas]
# 944  [citywalk, universal, restaurants, margaritaville, shops, clubs, orlando, bars, bubba, disney, studios, shopping, entertainment, music, dinner, gump, theme, atmosphere, cinema, nightlife]
# 890  [zoo, lincoln, chicago, zoos, gorillas, lights, enclosures, brookfield, lions, conservatory, gorilla, polar, monkeys, animal, apes, downtown, zoo39s, ape, giraffes, tigers]
# 11   [hershey, rides, coasters, hersheypark, roller, amusement, chocolate, lines, coaster, waterpark, classpartialentryspan, tickets, theme, candylane, zoo, disney, christmas, boardwalk, kiddie, rollercoasters]

# %%
the_park = park_groups_df[park_groups_df['name'].str.contains("Indiana Dunes")][['park_id','name','state','total_visit','cluster_assignment','park_features']]
the_park
pd.set_option('display.max_colwidth',-1)
query_cluster =park_groups_df.loc[the_park['park_id']]['cluster_assignment']
season = 'Fall'
visit_type = 'Families'
cluster_name = 'cluster'+'_'+str(query_cluster)
cluster_name = (park_groups_df[park_groups_df['cluster_assignment']==query_cluster.values[0]]
                .sort_values([season,'stars','total_visit',visit_type],ascending=False)
               [['park_id','name','state','stars',season,visit_type,'total_visit','park_features']])
cluster_name.head(30)
# Out:
#       park_id                                             name  \
# 884   901      Torrey Pines State Natural Reserve
# 282   288      Chincoteague National Wildlife Refuge
# 725   737      Presque Isle State Park
# 80    81       Bahia Honda State Park and Beach
# 821   836      Fort De Soto Park
# 92    94       Peninsula State Park
# 896   915      Myrtle Beach State Park
# 310   316      Race Point Beach
# 888   905      Lovers Key State Park
# 133   135      Wai anapanapa State Park
# 130   132      Cape Henlopen State Park
# 694   706      Herring Cove Beach
# 28    28       Padre Island National Seashore
# 420   428      Ruby Beach
# 72    73       Point Reyes Seashore National Park
# 176   179      Sand Beach
# 180   183      Gulf Islands National Seashore Florida District
# 182   186      Cape Cod National Seashore
# 893   912      Discovery Park
# 53    53       Indiana Dunes State Park
# 596   606      Coast Guard Beach
# 490   498      Rialto Beach
# 1018  1041     Little Talbot Island State Park
# 505   513      Assateague Beach
# 147   150      Kaloko Honokohau National Historical Park
# 151   154      Canaveral National Seashore
# 381   389      Cape Hatteras National Seashore
# 187   191      Sandy Hook Gateway National Recreation Area
# 718   730      Back Bay National Wildlife Refuge
# 218   222      Johnson Beach
#
#                state     stars   Fall  Families  total_visit  \
# 884   California      4.715514  466.0  687.0     2404.0
# 282   Virginia        4.772349  454.0  699.0     1862.0
# 725   Pennsylvania    4.751285  429.0  698.0     1888.0
# 80    Florida         4.478992  391.0  626.0     2217.0
# 821   Florida         4.632124  351.0  548.0     1917.0
# 92    Wisconsin       4.717145  341.0  297.0     1087.0
# 896   South Carolina  4.445774  278.0  510.0     1233.0
# 310   Massachusetts   4.658037  251.0  213.0     895.0
# 888   Florida         4.645019  249.0  402.0     1542.0
# 133   Hawaii          4.759624  248.0  287.0     1136.0
# 130   Delaware        4.663963  203.0  293.0     846.0
# 694   Massachusetts   4.600324  175.0  108.0     604.0
# 28    Texas           4.535262  173.0  413.0     1082.0
# 420   Washington      4.784571  165.0  176.0     666.0
# 72    California      4.731366  160.0  116.0     629.0
# 176   Maine           4.453649  154.0  163.0     491.0
# 180   Florida         4.840399  141.0  270.0     785.0
# 182   Massachusetts   4.791667  130.0  99.0      370.0
# 893   Washington      4.523214  116.0  118.0     550.0
# 53    Indiana         4.457256  112.0  183.0     494.0
# 596   Massachusetts   4.654589  110.0  126.0     402.0
# 490   Washington      4.743590  108.0  106.0     423.0
# 1018  Florida         4.615711  97.0   126.0     467.0
# 505   Virginia        4.745958  91.0   180.0     428.0
# 147   Hawaii          4.465011  88.0   115.0     427.0
# 151   Florida         4.792757  83.0   119.0     487.0
# 381   North Carolina  4.756410  82.0   124.0     379.0
# 187   New Jersey      4.418462  69.0   65.0      324.0
# 718   Virginia        4.576763  61.0   82.0      238.0
# 218   Florida         4.688716  59.0   87.0      253.0
#
#                                                                                                                                                                             park_features
# 884   [torrey, beach, pines, ocean, diego, san, reserve, cliffs, pacific, jolla, coast, razor, golf, pine, beaches, la, fleming, tide, gliders, california]
# 282   [ponies, chincoteague, beach, refuge, lighthouse, assateague, horses, island, beaches, spray, bug, pony, mosquitoes, biking, mosquitos, tom39s, ocean, bikes, marsh, bird]
# 725   [presque, beaches, isle, erie, beach, peninsula, biking, fishing, boat, lighthouse, sunsets, pa, swimming, perry, rentals, boating, sand, bay, waves, lighthouses]
# 80    [beach, bahia, keys, honda, beaches, snorkeling, snorkel, seaweed, key, bridge, sand, sandspur, florida, sea, looe, shallow, fish, ocean, sandy, swimming]
# 821   [beach, fort, soto, beaches, desoto, pier, fishing, sand, florida, dolphins, kayak, gulf, pinellas, piers, kayaking, shells, tampa, pete, campground, fish]
# 92    [peninsula, lighthouse, beach, biking, eagle, tower, nicolet, county, door, bay, bikes, golf, wisconsin, bluff, biked, rent, rented, campsites, fish, theater]
# 896   [beach, myrtle, pier, fishing, mb, huntington, campground, beaches, ocean, fish, shells, mbsp, boardwalk, sc, shelters, campsites, sand, strand, cabins, cream]
# 310   [beach, seals, provincetown, cape, race, sand, whales, dunes, ptown, cod, beaches, ocean, seashore, herring, shore, whale, waves, swimming, cove, lighthouse]
# 888   [beach, shells, myers, tram, key, beaches, shelling, lovers, kayak, manatees, sand, kayaking, manatee, kayaks, lover39s, dolphins, fort, sanibel, rent, florida]
# 133   [hana, beach, sand, lava, caves, wai39anapanapa, cave, maui, blowhole, waves, blow, ocean, swim, tube, tubes, beaches, hole, swimming, crashing, surf]
# 130   [beach, henlopen, cape, lewes, beaches, rehoboth, delaware, ocean, fishing, pier, dunes, wwii, biking, bikes, fort, surf, sand, bath, towers, bay]
# 694   [beach, herring, cove, provincetown, cape, ptown, sand, beaches, race, dunes, cod, sunsets, tide, seashore, whales, gay, ocean, waves, snack, showers]
# 28    [beach, padre, seashore, corpus, beaches, island, sand, christi, seaweed, malaquite, turtle, release, sea, turtles, texas, gulf, fishing, showers, surf, shells]
# 420   [beach, ruby, tide, driftwood, stacks, sea, olympic, beaches, pools, logs, rialto, ocean, coast, pacific, seastacks, starfish, 101, anemones, sand, peninsula]
# 72    [reyes, lighthouse, seashore, beach, seals, beaches, elk, elephant, san, francisco, tomales, tule, whales, ocean, earthquake, pt, california, drake39s, bay, chimney]
# 176   [beach, sand, acadia, maine, sandy, ocean, waves, beaches, swimming, rocky, swim, cliffs, rooms, tide, beehive, sea, stairs, seaweed, granite, shells]
# 180   [beach, beaches, pensacola, pickens, gulf, sand, seashore, fort, navarre, islands, dunes, sugar, perdido, emerald, sands, florida, pristine, shells, island, unspoiled]
# 182   [cape, cod, seashore, beach, beaches, provincetown, dunes, seals, nauset, lighthouses, marconi, eastham, sand, ocean, waves, salt, wellfleet, coast, pond, shore]
# 893   [seattle, lighthouse, beach, discovery, puget, sound, lawton, rainier, magnolia, downtown, woods, beaches, bluff, olympic, military, blackberries, fort, olympics, meadows, mt]
# 53    [dunes, beach, indiana, dune, michigan, sand, lakeshore, chicago, beaches, challenge, campground, baldy, chesterton, lifeguards, swimming, shore, swim, waves, sandy, skyline]
# 596   [beach, seals, cape, shuttle, guard, cod, waves, beaches, coast, sand, nauset, seashore, surf, tide, ocean, eastham, dunes, tram, boogie, salt]
# 490   [beach, rialto, driftwood, tide, stacks, olympic, pools, logs, beaches, hole, sea, waves, wall, holeinthewall, pacific, ruby, starfish, seastacks, coast, ocean]
# 1018  [beach, talbot, jacksonville, beaches, island, florida, shells, sand, campground, driftwood, dunes, tide, amelia, jax, showers, marsh, campsites, unspoiled, fishing, boardwalk]
# 505   [beach, assateague, ponies, chincoteague, island, horses, beaches, sand, ocean, shells, waves, dolphins, surf, showers, lifeguards, refuge, lighthouse, seashore, tom39s, maryland]
# 147   [turtles, beach, lava, sea, hawaiian, kona, fish, honokohau, marina, petroglyphs, turtle, harbor, kalokohonokohau, snorkeling, island, ponds, heiau, swimming, hawaii, airport]
# 151   [beach, seashore, canaveral, beaches, playalinda, florida, merritt, titusville, unspoiled, smyrna, sand, turtle, pristine, refuge, launch, surf, shells, waves, ocean, kennedy]
# 381   [hatteras, beach, seashore, beaches, lighthouse, cape, obx, ocracoke, dunes, banks, outer, nags, island, sand, bodie, ocean, lighthouses, unspoiled, inlet, shells]
# 187   [beach, hook, sandy, beaches, lighthouse, jersey, gunnison, nj, hancock, manhattan, shore, fort, ferry, nyc, nude, ocean, seastreak, sand, bay, biking]
# 718   [beach, refuge, bay, sandbridge, virginia, dunes, tram, snakes, va, ocean, false, cape, beaches, turtles, marshes, carolina, fishing, marsh, osprey, snake]
# 218   [beach, pensacola, johnson, perdido, gulf, sand, beaches, seashore, key, shells, dunes, fishing, secluded, sugar, johnson39s, waves, surf, showers, intercoastal, pavilions]
